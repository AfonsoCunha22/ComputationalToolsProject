# %% [markdown]
# # Salling Group API

# %% [markdown]
# The [Salling Group](https://www.bing.com/search?pglt=673&q=salling+group&cvid=f55d1d4c50804d25b06549d7cbb7c91f&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIGCAEQABhAMgYIAhAAGEAyBggDEAAYQDIGCAQQABhAMgYIBRAAGEAyBggGEAAYQDIGCAcQABhAMgYICBBFGDzSAQg0MzAyajBqMagCALACAA&FORM=ANNTA1&PC=LCTS), Denmark's largest grocery group, owns supermarket chains such as Føtex, Bilka, and Netto. This group provides a free API that offers access to data related to the supermarket business. Among the several APIs available, we are interested in two:
#
# - **Anti Food Waste:** This API is updated daily with products that are about to expire or need to be cleared, sold at reduced prices.
# - **Store:** This API provides a list of all the stores along with specific characteristics such as address, opening hours, and special attributes like bakery and florist services.

# %% [markdown]
# # Store API

# %% [markdown]
# **Limitation Note:** The API we are utilizing restricts data retrieval to a maximum of 20 stores per pager.

# %% [markdown]
# First, let's get to know our working area. Where can we use this program? Let's retrieve all stores and their locations.

# %%
# importing necessary packages
from geopy.geocoders import Nominatim
import geocoder
import requests
import pandas as pd
import math
import requests
from tabulate import tabulate
import folium
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objects as go

# %%
# Base URL
base_url = 'https://api.sallinggroup.com/v2/stores'

# key to have access to the api
headers = {
    'Authorization': 'Bearer a0b4ad91-e8d4-42ab-ae84-6cb3fd0f6024'
}

# Initialize page and per_page variables
page = 1
per_page = 20

# Initialize stores_info list
stores_info = []

while True:
    # Construct the URL for the current page
    url = f'{base_url}?page={page}&per_page={per_page}'

    # Make the request
    response = requests.get(url, headers=headers)

    # Break the loop if the request was not successful
    if response.status_code != 200:
        print("Failed to retrieve data. Status code:", response.status_code)
        break

    # Extract data from the response
    data = response.json()

    # Extract relevant information from JSON
    for store in data:
        store_info = [
            store['name'],
            store['brand'],
            store.get('phoneNumber', 'N/A'),  # 'N/A' if 'phoneNumber' is not present
            store['sapSiteId'],
            store['vikingStoreId'],
            store['address']['street'],
            store['address']['zip'],
            store['address']['city'],
            store['address']['country'],
            store['coordinates'],
            store['created'],
            store['modified'],
            store['id']
        ]
        stores_info.append(store_info)

    # Get the total count from the response headers
    total_count = int(response.headers.get('X-Total-Count', 0))

    # Calculate the total number of pages
    total_pages = math.ceil(total_count / per_page)

    # Calculate the remaining entities
    entities_remaining = total_count - (per_page * page)

    # If there are no more entities remaining, break the loop
    if entities_remaining <= 0:
        break

    # Increment the page number for the next iteration
    page += 1

# Create and print the table
headers = ["Name", "Brand", "Phone Number", "Sap Site Id", "Viking Store Id", "Street", "Zip", "City", "Country", "Coordinates", "Created", "Modified", "Id"]

# Convert the list of lists into a DataFrame
df = pd.DataFrame(stores_info, columns=headers)

print("Total number of stores:", total_count)
# Out:
# Total number of stores: 1762

# %% [markdown]
# To which stores this API can apply?

# %%
# distinct brands
df['Brand'].unique()
# Out:
# array(['bilka', 'salling', 'foetex', 'starbucks', 'carlsjr', 'netto',
#        'br'], dtype=object)

# %%
# how many stores are there for each brand
df['Brand'].value_counts()
# Out:
# Brand
# netto        1567
# foetex        111
# br             30
# bilka          19
# starbucks      16
# carlsjr        16
# salling         3
# Name: count, dtype: int64

# %% [markdown]
# A plot of all the stores will be created to enhance visual perception and help evaluate where our program can be extended. This visual representation will allow us to better understand the geographic distribution of the stores and identify potential areas for program expansion.

# %%
brand_colors = {
    'netto': 'blue',
    'bilka': 'red',
    'salling': 'grey',
    'foetex': 'green',
    'starbucks': 'purple',
    'carlsjr': 'orange',
    'br': 'black'
}

# Initialize a map centered around Copenhagen, Denmark:
enhanced_visibility_map = folium.Map(location=[55.6761, 12.5683], zoom_start=5)

# Plot each store as a dot on the map, enhancing visibility with increased radius and borders
for idx, row in df.iterrows():
    # Extract the longitude and latitude from the Coordinates column
    # The coordinates are swapped here to be in the order (longitude, latitude)
    corrected_location = [row['Coordinates'][1], row['Coordinates'][0]]
    # Assign a color based on the store's brand
    color = brand_colors.get(row['Brand'].lower(), 'gray')  # Default to gray if brand not found
    # Create an enhanced visibility dot for the scatter plot
    folium.CircleMarker(
        location=corrected_location,
        radius=5,  
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=1,
        weight=1,  
        popup=f"{row['Name']} ({row['Brand']}) - {row['Country']}"
     ).add_to(enhanced_visibility_map)

# Save the map to an HTML file for viewing
enhanced_visibility_map_path = 'data/enhanced_visibility_map.html'
enhanced_visibility_map.save(enhanced_visibility_map_path)
enhanced_visibility_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83ead53018ef934b4119e56c88b0e724 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83ead53018ef934b4119e56c88b0e724&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83ead53018ef934b4119e56c88b0e724 = L.map(
#                 &quot;map_83ead53018ef934b4119e56c88b0e724&quot;,
#                 {
#                     center: [55.6761, 12.5683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34041d2043760c9bef8a9b97eaafb0b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_34041d2043760c9bef8a9b97eaafb0b2.addTo(map_83ead53018ef934b4119e56c88b0e724);
#
#
#             var circle_marker_64dfa720d1e2e1e64f34137e3fa862c2 = L.circleMarker(
#                 [56.182413, 10.104849],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_83ead53018ef934b4119e56c88b0e724);
#
#
#         var popup_c9056003ee3280ce137bb1881a458fbf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f6893ebffd5e2e1bce093474af6b7f6 = $(`&lt;div id=&quot;html_9f6893ebffd5e2e1bce093474af6b7f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bilka Tilst (bilka) - DK&lt;/div&gt;`)[0];
#                 popup_c9056003ee3280ce137bb1881a458fbf.setContent(html_9f6893ebffd5e2e1bce093474af6b7f6);
#
#
#
#         circle_marker_64dfa720d1e2e1e64f34137e3fa862c2.bindPopup(popup_c9056003ee3280ce137bb1881a458fbf)
#         ;
#
#
#
#
#             var circle_marker_8b567450092aa794d5ca04e37ec75825 = L.circleMarker(
#                 [57.004687, 9.876099],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_83ead53018ef934b4119e56c88b0e724);
#
#
#         var popup_8eba416054ce2d695bb0c9b9102a512b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50d297cab6e9ab4b75ac4a4494d2ccc1 = $(`&lt;div id=&quot;html_50d297cab6e9ab4b75ac4a4494d2ccc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bilka Skalborg (bilka) - DK&lt;/div&gt;`)[0];
#                 popup_8eba416054ce2d695bb0c9b9102a512b.setContent(html_50d297cab6e9ab4b75ac4a4494d2ccc1);
#
#
#
#         circle_marker_8b567450092aa794d5ca04e37ec75825.bindPopup(popup_8eba416054ce2d695bb0c9b9102a512b)
#         ;
#
#
#
#
#             var circle_marker_4186fed0aa4a59a478839f40ad5fa8c3 = L.circleMarker(
#                 [55.5972696, 12.3247286],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_83ead53018ef934b4119e56c88b0e724);
#
#
#         var popup_5ef45fff427ae73fd96b91df44fb8e84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93be0eddfabcc1a1ed6e63cc30c18292 = $(`&lt;div id=&quot;html_93be0eddfabcc1a1ed6e63cc30c18292&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bilka Waves, Hundige (bilka) - DK&lt;/div&gt;`)[0];
#                 popup_5ef45fff427ae73fd96b91df44fb8e84.setContent(html_93be0eddfabcc1a1ed6e63cc30c18292);
#
#
#
#         circle_marker_4186fed0aa4a59a478839f40ad5fa8c3.bindPopup(popup_5ef45fff427ae73fd96b91df44fb8e84)
#         ;
#
#
#
#
#             var circle_marker_92b0d81c29887029cdbc08bc0c83f060 = L.circleMarker(
#                 [55.37802, 10.43145],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &qu

# %%
#brand per country
df.groupby('Country')['Brand'].value_counts()
# Out:
# Country  Brand
# DE       netto        340
# DK       netto        553
#          foetex       111
#          br            30
#          bilka         19
#          carlsjr       16
#          starbucks     16
#          salling        3
# PL       netto        674
# Name: count, dtype: int64

# %% [markdown]
# It is evident that Netto represents the most prominent brand (depicted in blue on the map), with a total of 1,548 stores across multiple countries. Notably, Netto has a significant presence in Poland and Germany, boasting more stores in Poland than in Denmark. This distribution implies that our program can be feasibly extended to these three countries. Data for all other stores, apart from Netto, is only available for Denmark.

# %% [markdown]
# # Food API

# %% [markdown]
# ## API connection

# %% [markdown]
# The ingredients sourced through this API are typically those nearing expiration or surplus stock that supermarkets wish to clear, possibly due to past campaigns or minor defects. This API is rich in data, providing crucial information on ingredient descriptions, pricing, and discount values that we need to assimilate and utilize effectively.

# %% [markdown]
# Let's analyze how data is retrieved for each store.

# %%
import time
import requests

def get_products_in_stores(store_ids):
    '''function that given a list of store ids will return all the products in those stores'''
    filtered_data = []
    batch_size = 4
    time.sleep(5) 

    unprocessed_store_ids = []
    no_food_waste_count = 0
    food_waste_count = 0

    for i in range(0, len(store_ids), batch_size):
        batch = store_ids[i:i + batch_size]
        for store_id in batch:
            url = f'https://api.sallinggroup.com/v1/food-waste/{store_id}'
            headers = {
                'Authorization': 'Bearer a0b4ad91-e8d4-42ab-ae84-6cb3fd0f6024'
            }

            while True:
                response = requests.get(url, headers=headers)
                if response.status_code == 200:
                    # Request was successful
                    data = response.json()
                    filtered_data.append(data)
                    print(f"Retrieved data for store id: {store_id}")
                    food_waste_count += 1
                    break

                elif response.status_code == 429:
                    # Too many requests, wait and retry
                    print("Rate limit exceeded. Adding store id to unprocessed list")
                    unprocessed_store_ids.append(store_id)
                    break
                else:
                    # Request failed
                    print("Failed to retrieve data. Status code:", response.status_code)
                    #unprocessed_store_ids.append(store_id)
                    no_food_waste_count += 1

                    break
        
        # Wait before processing the next batch
        if i + batch_size < len(store_ids):
            print("Waiting before processing the next batch...")
            time.sleep(10) #we had to test several times to see how much time we needed to wait before making the next request

    # Retry fetching data for unprocessed store IDs
    if unprocessed_store_ids:
        print("Retrying unprocessed store IDs...")
        print("Unprocessed store IDs:", unprocessed_store_ids)
        time.sleep(10)  # Wait before retrying
        filtered_data.extend(get_products_in_stores(unprocessed_store_ids))

    print(f"Number of stores with no food waste data: {no_food_waste_count}")

    return filtered_data, food_waste_count ,no_food_waste_count

# %% [markdown]
# A delay was added since the api has a limit of requests.

# %% [markdown]
# The data is organized by store and retrieves all clearance products—items that the supermarket wishes to remove from the shelves due to their imminent expiration dates. For each product, the system provides an offer (price, applied discount, etc.) and a product description (name, image, etc.). Although the product descriptions are in Danish, we have an English category hierarchy. We have decided to use the leftmost category as the final product description.
#
# Example:\
# categories: {'da': 'Mejeri & køl>Færdigretter>Middagsretter', 'en': 'Dairy And Cold Storage>Ready To Eat Meals>Dinner Meals'}\
# description: NASI GORENG NÆMT\
# ean: 5712877396463\
# image: None

# %%
def get_columns_categories(data):
    flattened_data = []
    for entry in data:
        store = entry['store']
        for clearance in entry['clearances']:
            offer = clearance['offer']
            product = clearance['product']

            categories_da = product.get('categories', {}).get('da', None)
            categories_en = product.get('categories', {}).get('en', None)

            # Initialize categories to None
            cat1 = cat2 = cat3 = cat4 = None

            # Only proceed with splitting if categories_en is not None
            if categories_en:
                categories_split = categories_en.split('>')

                # Assign categories based on index
                if len(categories_split) >= 4:
                    cat4 = ">".join(categories_split[:-3])
                    cat3 = categories_split[-3]
                    cat2 = categories_split[-2]
                    cat1 = categories_split[-1]
                elif len(categories_split) == 3:
                    cat3 = categories_split[-3]
                    cat2 = categories_split[-2]
                    cat1 = categories_split[-1]
                elif len(categories_split) == 2:
                    cat2 = categories_split[-2]
                    cat1 = categories_split[-1]
                else:
                    cat1 = categories_split[-1]

            flattened_data.append({
                'Store id': store['id'],
                'Store Name': store['name'],
                'Store Address': store['address']['street'],
                'Store City': store['address']['city'],
                'Store Zip': store['address']['zip'],
                'Store Brand': store['brand'],
                'Description': product['description'],
                'EAN': product['ean'],
                'Categories (da)': categories_da,
                'Categories (en)': categories_en,
                'Category 1': cat1,
                'Category 2': cat2,
                'Category 3': cat3,
                'Category 4': cat4,
                'Image': product['image'],
                'Currency': offer['currency'],
                'Original Price': offer['originalPrice'],
                'New Price': offer['newPrice'],
                'Discount': offer['discount'],
                'Percent Discount': offer['percentDiscount'],
                'Start Time': offer['startTime'],
                'End Time': offer['endTime'],
                'Stock': offer['stock'],
                'Stock Unit': offer['stockUnit']
            })

    # Create DataFrame if there is data
    if flattened_data:
        salling_data = pd.DataFrame(flattened_data)
    else:
        print("No data available to process.")
    return salling_data

# %%
def salling_processing(store_ids):
    '''final function that given a address and distance it retrieves all information
    from the closest stores within the radius, if adrress is None IP adrress will be retrieved coordinates
    '''
    data, stores_with_food_waste, stores_with_no_food_waste = get_products_in_stores(store_ids)
    salling_data = get_columns_categories(data)

    # Apply data cleaning
    salling_data.dropna(subset=['Categories (en)'], inplace=True)
    salling_data.drop_duplicates(inplace=True)
    return salling_data, stores_with_food_waste, stores_with_no_food_waste

# %%
# i want to apply this to the cluster picke whrere we have a dictionary with cluster id and then a list with all the stores
# that belong to that cluster
# and then we can apply the function to each cluster

def get_products_in_clusters(clusters):
    '''function that given a dictionary with cluster id and a list of store ids will return all the products in those stores'''
    cluster_data = {}
    cluster_data_quality = {}
    for cluster_id, store_ids in clusters.items():
        print(f"Processing cluster {cluster_id}...")
        print(f"Number of stores in cluster: {len(store_ids)}")
        cluster_data[cluster_id], food_waste_count, no_food_waste_count = salling_processing(store_ids)
        cluster_data_quality[cluster_id] = {
            'No. Stores with Food Waste': food_waste_count,
            'No. Stores without Food Waste': no_food_waste_count
        }
    return cluster_data, cluster_data_quality

# %%
# we will apply this function to the clusters dictionary
# read pickle file
clusters = pd.read_pickle('data/cluster_store_dict.pkl')
# print in a dataframe the cluster number and the number of stores in that cluster
clusters_df = pd.DataFrame(clusters.items(), columns=['Cluster', 'Store Ids'])
clusters_df['Number of Stores'] = clusters_df['Store Ids'].apply(len)
print(f"There are {len(clusters_df)} clusters in the dataset.")
clusters_df.head()
# Out:
# There are 54 clusters in the dataset.
#    Cluster                                          Store Ids  \
# 0        0  [efba0457-090e-4132-81ba-c72b4c8e7fee, f9b13c0...
# 1        1  [937e257e-078d-403f-b427-572dd0ca22e5, da5291d...
# 2        2  [c6744248-cf95-43c3-aa43-d3daef2aeb4b, 88f9595...
# 3        3  [f897964d-2890-49bb-90f6-86f12b11afe6, b2c038d...
# 4        4  [e30f0fb7-52c0-4265-be91-8f39108978b4, 52fa68c...
#
#    Number of Stores
# 0                 7
# 1                 9
# 2                10
# 3                11
# 4                 6

# %%
salling_data, clusters_quality = get_products_in_clusters(clusters)
print("Data processing completed.")
# Out:
# Processing cluster 0...
# Number of stores in cluster: 7
# Retrieved data for store id: efba0457-090e-4132-81ba-c72b4c8e7fee
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: cc0a422b-fbad-4ca7-a78c-43a46bb0fe5b
# Retrieved data for store id: f14ae3b5-9c98-4bf8-869a-1ec74a1d73a1
# Waiting before processing the next batch...
# Retrieved data for store id: 1c7a633b-05dd-40d4-90d7-4cb8deb37db7
# Retrieved data for store id: edcacf87-af62-40ec-a30f-e7d445acdd83
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 1...
# Number of stores in cluster: 9
# Retrieved data for store id: 937e257e-078d-403f-b427-572dd0ca22e5
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 2da2b92a-25c8-48cf-a4a1-7c56b4469a02
# Waiting before processing the next batch...
# Retrieved data for store id: 4edfa4fd-ccbb-44dd-a0f2-efcb5c609331
# Retrieved data for store id: 287be12a-741b-407f-ba4a-0a2c1238ec50
# Retrieved data for store id: 59790dc9-193f-4a81-a89b-35329933b0fa
# Retrieved data for store id: 1a3a385a-f1e4-4b43-bc65-aa4190a0925b
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 3
# Processing cluster 2...
# Number of stores in cluster: 10
# Retrieved data for store id: c6744248-cf95-43c3-aa43-d3daef2aeb4b
# Retrieved data for store id: 88f95957-9e50-43ae-9526-69962e4b884c
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 2b07278a-fc26-463b-ad5c-49800be06e85
# Waiting before processing the next batch...
# Retrieved data for store id: 3014420d-914a-4f3f-b4d7-d3a41112aa9c
# Retrieved data for store id: b7847809-4835-4bfa-9056-9cbb53046c47
# Retrieved data for store id: edfa1a6c-552a-40f4-9b49-9081f800bed6
# Retrieved data for store id: abf645e5-2c6d-4518-80b7-f3c489a85d35
# Waiting before processing the next batch...
# Retrieved data for store id: 52dae892-f661-4368-9c51-e8834871d99f
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 3...
# Number of stores in cluster: 11
# Retrieved data for store id: f897964d-2890-49bb-90f6-86f12b11afe6
# Retrieved data for store id: b2c038d8-f0c0-4712-b145-b9336a041837
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 02545e07-6585-43ff-bfbf-09a076fc64f0
# Waiting before processing the next batch...
# Retrieved data for store id: bc87bb9c-3393-4b88-ae6a-70fee09b900d
# Retrieved data for store id: d0f79858-5441-450d-a37e-8c1f74cb375b
# Retrieved data for store id: 9d13c9cb-4d85-4fe5-97d5-394896560dfc
# Retrieved data for store id: c4cd9331-1892-472d-9a53-4758cef2d348
# Waiting before processing the next batch...
# Retrieved data for store id: 6ee54581-9368-4fed-9129-11758c2925cb
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 3
# Processing cluster 4...
# Number of stores in cluster: 6
# Retrieved data for store id: e30f0fb7-52c0-4265-be91-8f39108978b4
# Retrieved data for store id: 52fa68c5-19d8-402e-82d1-cf538ff5f614
# Retrieved data for store id: 72b00e0c-2b1d-4348-83d8-132aad2bb7a8
# Retrieved data for store id: 78b1c192-44c8-4656-a2d6-95463e8a4ec4
# Waiting before processing the next batch...
# Retrieved data for store id: 47dcf695-104f-4b90-a732-b8106ff029e6
# Retrieved data for store id: 99e1ac35-79a1-4e8c-afba-cc4c778fe3b0
# Number of stores with no food waste data: 0
# Processing cluster 5...
# Number of stores in cluster: 9
# Retrieved data for store id: 623d58b2-1c34-45ca-b076-75c1adc32c1e
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 34e76e73-5925-4d78-b994-7c1f42e749a4
# Retrieved data for store id: 01ca7997-68bf-4ec9-ac2c-4a422731a728
# Waiting before processing the next batch...
# Retrieved data for store id: d6bce993-b26c-4261-823f-5bc2eeacbf8e
# Retrieved data for store id: dffb3fd3-6a18-4657-ab3b-ea200a2b7249
# Retrieved data for store id: 0e4f3d57-0b2a-400b-bc77-d737763dd2c7
# Retrieved data for store id: 194e4354-e95a-4fbe-abde-3331b66cfda5
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 6...
# Number of stores in cluster: 9
# Retrieved data for store id: 62ef9ae8-8dd0-4f97-8c6e-dabb42d5f6b5
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: df192b7d-efcc-4514-af0e-0afd76e7ac96
# Waiting before processing the next batch...
# Retrieved data for store id: 954bc3c8-06a7-47e1-9409-19be9d80e045
# Retrieved data for store id: 7c07a4a0-9600-472b-a823-ab67edab1371
# Retrieved data for store id: 4711cf77-5baa-40a7-8498-40ce33fbfb82
# Retrieved data for store id: 7062ea13-f17f-460a-b6a2-e6cdb33f369f
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 3
# Processing cluster 7...
# Number of stores in cluster: 6
# Retrieved data for store id: 84403add-6c5f-48fc-8ea4-87279b6bc067
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: efd13072-4685-4b33-a544-f702b64498b7
# Retrieved data for store id: c280fbc4-2fab-4260-84f6-7fba1f2584a4
# Waiting before processing the next batch...
# Retrieved data for store id: f621a1a1-ee70-4559-9e8f-9dc7ea12be46
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 8...
# Number of stores in cluster: 10
# Retrieved data for store id: d4c4e2e4-f67f-4aec-b249-e3a4ad3fc820
# Retrieved data for store id: 9efb2271-4cfb-49c1-9155-b2a038360cb2
# Retrieved data for store id: 12480e12-729a-4324-9570-ea1904dc2304
# Retrieved data for store id: 3aba940c-f246-400d-a969-c28f33ea7e35
# Waiting before processing the next batch...
# Retrieved data for store id: ace63c71-2fb5-4327-824e-9fbf57f3aa56
# Retrieved data for store id: 448f9506-c0d6-4c43-a4d2-96f7ac9e39a6
# Retrieved data for store id: 8acb7bbf-3154-404c-9580-b95c8ded3e03
# Retrieved data for store id: 0d9a0b11-9c4e-4f86-9d48-ddcecadbac18
# Waiting before processing the next batch...
# Retrieved data for store id: dcfd6dca-4e6c-4671-a1c4-8f9f1cd51d66
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 10...
# Number of stores in cluster: 11
# Retrieved data for store id: 15269c38-5e82-48ff-bf74-ac0276f4f90b
# Retrieved data for store id: f025445d-d688-41f3-8d13-b4844e545533
# Retrieved data for store id: 9b0214b9-811f-4f49-86c9-c8ebe33c56de
# Failed to retrieve data. Status code: 400
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 2051b4e8-6c75-47e3-b569-019363bbf623
# Retrieved data for store id: cc63a1bd-311d-4b80-a048-b2c591a81c20
# Retrieved data for store id: 35b67d0f-08e8-434f-86aa-a04ef4917364
# Waiting before processing the next batch...
# Retrieved data for store id: 70bd812b-1bda-432a-bd9e-0024d3ee06f5
# Retrieved data for store id: 270e2835-85f7-4452-8bc3-6f936ec2794e
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 3
# Processing cluster 11...
# Number of stores in cluster: 7
# Retrieved data for store id: a53014d5-cd36-471c-a192-69aa1d4c8c89
# Retrieved data for store id: 3407d722-9dce-453a-8fb8-3a2928bfa023
# Retrieved data for store id: 07631afc-e5b9-4561-a21f-1b72174aff50
# Retrieved data for store id: 3195edfc-e035-43e6-babf-df8419b85749
# Waiting before processing the next batch...
# Retrieved data for store id: 3d41657a-5e19-4cc4-9ab1-e783b07d2607
# Retrieved data for store id: 9f5bd205-3118-4d06-800d-cfe65e88dbda
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 12...
# Number of stores in cluster: 13
# Retrieved data for store id: 7feb6abe-ab40-4148-84b8-429c3d740cc5
# Retrieved data for store id: fc38a711-6083-4341-ab92-78e0e54252ac
# Retrieved data for store id: b3c7071f-5db7-4722-b2e4-2b614bb31686
# Retrieved data for store id: 93c8355f-f760-4215-a5ac-87ab2e595e72
# Waiting before processing the next batch...
# Retrieved data for store id: dd48e5eb-7c35-41aa-8e25-4271440ef818
# Retrieved data for store id: 07a93352-73dc-4ce3-9de3-60496d7572c2
# Retrieved data for store id: 162ceb7d-24c6-43c9-a826-942e78656a73
# Retrieved data for store id: 37897bf3-e2bc-48bd-8dc4-34c8104d0d97
# Waiting before processing the next batch...
# Retrieved data for store id: 63f2324e-f361-42eb-ad05-a3afffdde74e
# Retrieved data for store id: 37e65637-451c-4dfd-a778-eb86a9cdc216
# Retrieved data for store id: 60a92065-e61b-4020-9f5e-972a0e8b7d3e
# Retrieved data for store id: e38106ab-2566-4daa-bf0a-39cb4d61a10f
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 13...
# Number of stores in cluster: 9
# Retrieved data for store id: 9c3a7de5-8b92-407d-9dbe-9f455482b532
# Retrieved data for store id: db887550-a38d-4dd6-82a0-2884f8b070df
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: fe1b32a9-ddd2-485f-8fe6-93af6bfe8808
# Waiting before processing the next batch...
# Retrieved data for store id: 51d828b9-695c-44ed-bea4-c45a3cf839a8
# Retrieved data for store id: 97448272-ace1-47e5-ab9a-08298cedc415
# Retrieved data for store id: 87647462-de62-4e6b-a19d-b7f237ad87dd
# Retrieved data for store id: 5e2aef90-6c4a-4918-b1e8-df20ba06b65e
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 14...
# Number of stores in cluster: 6
# Retrieved data for store id: fb290d6a-14ff-468f-8740-ddb8addb0833
# Retrieved data for store id: 7f557dca-e186-4b70-a9e5-c141bfde5621
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: a2ae41ba-f16d-45d6-a424-70b34c2ceb92
# Waiting before processing the next batch...
# Retrieved data for store id: e289d9b0-6e7a-4a54-a5c4-f0b306f9018a
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 15...
# Number of stores in cluster: 6
# Retrieved data for store id: 5b5f4ee4-cce8-47b9-8358-6c4e82d055b0
# Retrieved data for store id: 15a4b863-66fb-4bba-9978-cfd1af0dd70c
# Retrieved data for store id: f609fd5f-99de-495a-b986-4d6935e85dca
# Retrieved data for store id: 170b4f1a-a29c-4b07-a391-d7bb23062911
# Waiting before processing the next batch...
# Retrieved data for store id: a7d29537-e706-485b-aba2-9bed374b8c87
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 16...
# Number of stores in cluster: 6
# Retrieved data for store id: b77a319b-463e-438d-8191-94c19a8f8ea2
# Retrieved data for store id: b0d91cf8-d58e-4f67-8ca4-e990a13b3802
# Retrieved data for store id: 8710a1fc-c8cd-4708-8035-667ea7ff5afd
# Retrieved data for store id: 7f0275f8-6008-436b-91fb-45e8dfcf9c0b
# Waiting before processing the next batch...
# Retrieved data for store id: a967ecd1-a0d3-40d6-ae20-1a850b056867
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 18...
# Number of stores in cluster: 5
# Retrieved data for store id: 475ef605-2081-4b36-80f8-746138b4f2f9
# Retrieved data for store id: fcf6af86-f073-4abe-8bce-41d8190a6bbe
# Retrieved data for store id: 687e966c-55bf-4765-a5cc-f3637fc1de49
# Failed to retrieve data. Status code: 400
# Waiting before processing the next batch...
# Retrieved data for store id: abfab2ad-2fae-4357-b055-ccdb9da1e8ac
# Number of stores with no food waste data: 1
# Processing cluster 19...
# Number of stores in cluster: 15
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: da2957d5-67ec-4f24-9c49-235b6712e063
# Waiting before processing the next batch...
# Retrieved data for store id: 5a5a3b85-1c8c-433e-a56c-23f6326306f7
# Retrieved data for store id: 78c129a0-6273-475f-9640-cec700f11948
# Retrieved data for store id: 1d0ee0d4-9b92-40b6-b799-6936b8742828
# Retrieved data for store id: 1b675388-1c81-4c11-84c6-c9aaaa4d2402
# Waiting before processing the next batch...
# Retrieved data for store id: 67766b50-4cc6-4658-8fc4-a9b2db468f91
# Retrieved data for store id: 100d809a-cec0-43b3-a9b4-83564cf71d35
# Retrieved data for store id: 888e002d-791b-4397-a799-99bcb84f1e36
# Retrieved data for store id: cae14931-51f7-462d-81dd-7b78c1621507
# Waiting before processing the next batch...
# Retrieved data for store id: 18a97dbd-c483-4a76-b1d7-2881ccc4d884
# Retrieved data for store id: 445ec277-02ec-4d82-bef5-0fb302d040d3
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 4
# Processing cluster 20...
# Number of stores in cluster: 9
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: d6abf195-312b-4818-8933-bda8ecdd9fbd
# Retrieved data for store id: 26d28dd0-0205-413d-967f-bfbda8b9c947
# Failed to retrieve data. Status code: 400
# Waiting before processing the next batch...
# Retrieved data for store id: f80a21f3-6c93-4326-8782-8f8a2f6b3dfa
# Retrieved data for store id: dcd139fe-e427-4849-b2c6-aab21e502916
# Retrieved data for store id: 97df1790-97f6-4903-9866-6e420fb4942c
# Retrieved data for store id: 367a22b8-0ff4-4686-99c8-f238e4fb01b2
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 3
# Processing cluster 23...
# Number of stores in cluster: 12
# Retrieved data for store id: 75201b89-dca6-4bc6-aaab-84907f36caf7
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 82595089-fc63-4fd5-a481-94140ecb2e2c
# Waiting before processing the next batch...
# Retrieved data for store id: 0e6f15e1-797f-4933-8f60-352c9a789bc5
# Retrieved data for store id: ad4b20f7-c9aa-47ba-b9d2-eb51b186323b
# Retrieved data for store id: b0a00400-cfcf-4bab-a34e-e7233dde4bc8
# Retrieved data for store id: c65bfb92-a969-4b8d-a684-fd0dd1864618
# Waiting before processing the next batch...
# Retrieved data for store id: b1130d37-2505-4355-862b-01485c7620e7
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: ffd50c4f-1bd1-474a-bd84-175154f693fb
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 4
# Processing cluster 24...
# Number of stores in cluster: 7
# Retrieved data for store id: 7f25f843-7a9b-4bc6-80aa-16a8c74c635b
# Retrieved data for store id: e227fed1-186b-4d4c-b7ff-41df5333c7b9
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 52dca4c7-882e-44d8-9ea5-bb77a818fe74
# Waiting before processing the next batch...
# Retrieved data for store id: 0dc55476-3591-4826-ba04-9d133ab96d61
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 5e269293-56c8-45b2-a578-db06af5cc651
# Number of stores with no food waste data: 2
# Processing cluster 28...
# Number of stores in cluster: 11
# Retrieved data for store id: 6635fa7f-cbf9-4a8b-bcf3-cd4dc59374d4
# Retrieved data for store id: 2aea552c-29ae-40f6-a93d-b5e480907135
# Retrieved data for store id: b8c4042f-e4e7-42a4-b60a-af4035da5104
# Retrieved data for store id: 261fcf18-cc56-497d-a1d9-fab4dd3c743b
# Waiting before processing the next batch...
# Retrieved data for store id: cf6ebdd4-c54f-4f40-bf92-a2c635617719
# Retrieved data for store id: ac23b0ef-a76b-409c-ab87-4e85834912a4
# Retrieved data for store id: 80c9402d-4d0d-4b67-8887-62a7cfefedf5
# Retrieved data for store id: 5cb1d0ae-e5cd-4a2a-bf85-0abe7ecf650b
# Waiting before processing the next batch...
# Retrieved data for store id: 550c219f-55ff-4d6c-b662-24a2300d1908
# Retrieved data for store id: 6d53baf8-1077-4c29-89d0-24ab1f5cbf16
# Retrieved data for store id: 0cd7d167-adbf-4fa6-9396-7e779ccc264c
# Number of stores with no food waste data: 0
# Processing cluster 31...
# Number of stores in cluster: 8
# Retrieved data for store id: cf439a38-6d52-4277-b3f0-19d2b19f15ec
# Retrieved data for store id: 838de1eb-4c16-4053-8ccf-15ef96bdb3b4
# Retrieved data for store id: 942ffe1e-49f0-4e77-a28c-6bfa061fb80b
# Retrieved data for store id: fbc66aa7-c12e-4a9f-a4bd-8434bc251ca8
# Waiting before processing the next batch...
# Retrieved data for store id: 1c889a25-0c79-4b60-ac8e-d3fc0dcbe8a4
# Retrieved data for store id: 5b79d293-554c-4142-9880-96002202055e
# Retrieved data for store id: 7094712b-feda-4c89-b2e7-a384b13ae0e3
# Retrieved data for store id: 77f084bc-bb73-42de-9d25-7fb1d84a02b9
# Number of stores with no food waste data: 0
# Processing cluster 32...
# Number of stores in cluster: 13
# Retrieved data for store id: 895df17c-b8d3-47eb-8c46-fbde63c75058
# Retrieved data for store id: c4cba425-7f9c-475a-83ab-d51ed1907a0d
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: ef640999-4b98-4eb2-a18b-d5aedeecbaeb
# Waiting before processing the next batch...
# Retrieved data for store id: c8966c7d-4ba4-4123-909e-2339c2277be9
# Retrieved data for store id: 6b20f451-d1ad-43ba-ab20-e75d6174ff0d
# Retrieved data for store id: 338ad4f9-6432-40d9-93eb-e813f7d580e3
# Retrieved data for store id: 8f4e80ac-36c0-42ca-aa43-a1f6eb7d3a1a
# Waiting before processing the next batch...
# Retrieved data for store id: 1b160fb3-dc13-4142-ad7f-ed0c943b33e7
# Retrieved data for store id: e7f1523a-5e3f-4b03-8b77-a50b5a5e2cf1
# Retrieved data for store id: 6b87cd2b-ae47-47a9-a497-9cbcbfa1e01d
# Retrieved data for store id: 680e79c8-7a42-424b-bb73-21e1ad3cabd1
# Waiting before processing the next batch...
# Retrieved data for store id: 64547bbb-bae4-4f93-ba06-18372c51e1a5
# Number of stores with no food waste data: 1
# Processing cluster 33...
# Number of stores in cluster: 12
# Retrieved data for store id: 0847307a-6cf2-4c96-9d02-03e634dd1608
# Retrieved data for store id: 0e951ecc-9173-4296-bfca-8f0995971426
# Failed to retrieve data. Status code: 400
# Failed to retrieve data. Status code: 400
# Waiting before processing the next batch...
# Retrieved data for store id: 8a266e34-6a71-4aee-977a-590718fddec3
# Retrieved data for store id: b20359e6-194d-4a33-8dcb-05b01afa93c4
# Retrieved data for store id: 4c9e766e-5a4c-4641-aa07-5d8a89d83db9
# Retrieved data for store id: f184220d-0621-48eb-8f34-0c8c843b3764
# Waiting before processing the next batch...
# Retrieved data for store id: ede9b435-fdb9-4e86-9035-db4c38f38c4c
# Retrieved data for store id: 7de522de-9255-4f02-9015-40fd8bab3ecd
# Retrieved data for store id: 4cb9c03a-fa75-438f-beaf-587b21e8de1b
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 3
# Processing cluster 35...
# Number of stores in cluster: 7
# Retrieved data for store id: 55e1f3f1-7e9b-4507-97aa-95e36235946e
# Retrieved data for store id: ea69dae5-9683-4d3d-b065-b777df93388d
# Retrieved data for store id: 73d3e7b2-3325-4fa3-ab79-e59326fde93a
# Retrieved data for store id: d9719c92-566f-461a-86b6-9ed9c5d1b9e7
# Waiting before processing the next batch...
# Retrieved data for store id: 61eaa1ba-649b-4050-bcb9-d5e5585b3ae6
# Retrieved data for store id: ebaf3094-443b-4626-81ea-178c05b3a840
# Retrieved data for store id: 43217073-2a0d-4a79-8246-8c31dbb3ed1d
# Number of stores with no food waste data: 0
# Processing cluster 36...
# Number of stores in cluster: 5
# Retrieved data for store id: 0b0c825b-5604-4fa9-866f-242f7e6ae8b1
# Retrieved data for store id: df057e45-6c24-43c5-8a97-34539e75d7bb
# Retrieved data for store id: 8d5162d7-8bfb-43e0-9aae-fce045e7caf8
# Retrieved data for store id: b467f2e1-02c6-459b-9feb-e69c8ee8005d
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 37...
# Number of stores in cluster: 7
# Retrieved data for store id: 4956b28a-0bfd-4766-8146-ec2c70812e6a
# Retrieved data for store id: 0b52d54b-66e1-4d8c-a4a4-e243b5120946
# Retrieved data for store id: 78fe367c-cd14-4ccc-aef1-fd3a33687c09
# Retrieved data for store id: 68b426ec-4097-4c25-8842-c3ba12c63516
# Waiting before processing the next batch...
# Retrieved data for store id: c2f95cbd-f178-4080-b3c0-04a05a3ded65
# Retrieved data for store id: ef7dddbe-1113-4f75-9d33-739b07e4135d
# Retrieved data for store id: 3bffe23b-1d95-4370-a03a-65fbf55ce77a
# Number of stores with no food waste data: 0
# Processing cluster 38...
# Number of stores in cluster: 8
# Retrieved data for store id: d6a44e47-e54b-4486-839d-fe1fac9c514f
# Retrieved data for store id: b24b52fa-ee50-4fc5-839c-e546e8b32f75
# Retrieved data for store id: 8a20030f-db38-4b93-b4af-d40f7b1ee435
# Retrieved data for store id: 01dd4e7f-6fe3-4be8-867c-7f2b379b6d2d
# Waiting before processing the next batch...
# Retrieved data for store id: 118d8c5b-221f-47ff-96ea-39a5ee601290
# Retrieved data for store id: ad8cc733-2b8f-491e-a675-8143a18c99c5
# Retrieved data for store id: 3c49bbee-03a0-4966-b431-ea65d0e9992d
# Retrieved data for store id: b83bc543-12e4-4bf1-b837-24bc645421e1
# Number of stores with no food waste data: 0
# Processing cluster 39...
# Number of stores in cluster: 6
# Retrieved data for store id: ce36811a-e7d6-4737-b645-294b551c7c1f
# Retrieved data for store id: 70215fdb-4481-4cc4-b290-643ad1cf7353
# Retrieved data for store id: a53f07db-90b0-4816-912a-2779cf29c811
# Retrieved data for store id: 32765af8-0caa-4403-8d1c-594395216b89
# Waiting before processing the next batch...
# Retrieved data for store id: 38046af1-1a96-46a0-b239-bb0284c28efc
# Retrieved data for store id: 46032389-006d-439d-bf40-84e3d44097e1
# Number of stores with no food waste data: 0
# Processing cluster 41...
# Number of stores in cluster: 10
# Retrieved data for store id: a4ae5b26-ec5b-4331-8d52-f898ceef6c02
# Retrieved data for store id: d8018a37-0783-437e-999b-4fe15a56ac62
# Retrieved data for store id: d902d333-9f2c-432d-bd2c-fa823b80306b
# Retrieved data for store id: 8e7077fa-5ca2-49c7-a936-b7e7f75dfd0d
# Waiting before processing the next batch...
# Retrieved data for store id: cb1fdce2-9862-453b-8d22-a6d9abb2eaaf
# Retrieved data for store id: 4cae61c0-a460-4f1c-8ac1-d9e6dc06e03f
# Retrieved data for store id: 1b6a1a0d-de37-42dc-877f-921f079f8d82
# Retrieved data for store id: 7abf7dc3-b7c1-4637-8e0c-dab93c0cb164
# Waiting before processing the next batch...
# Retrieved data for store id: b4d0c52f-3642-4883-bd3c-bfd24492d18a
# Retrieved data for store id: dee09164-ffe8-484a-b6ba-31a6efa44fab
# Number of stores with no food waste data: 0
# Processing cluster 42...
# Number of stores in cluster: 6
# Retrieved data for store id: 88570006-2778-47cd-ac1f-001e2e1d47b0
# Retrieved data for store id: 8f2b27ec-8456-402c-bea5-d54a5e5c2033
# Retrieved data for store id: 582feac6-f66a-4fb0-8e83-3fd73c750576
# Retrieved data for store id: 8a19cc0e-bcb3-4994-bbe6-aa2d0dc58906
# Waiting before processing the next batch...
# Retrieved data for store id: dfc10374-5636-4e94-9bdc-f928bc799903
# Retrieved data for store id: 0eca728f-6b3a-4ae4-b036-942f62382eaf
# Number of stores with no food waste data: 0
# Processing cluster 43...
# Number of stores in cluster: 6
# Retrieved data for store id: e0615750-cd21-4e36-9bd5-73f4011327df
# Retrieved data for store id: 0971e272-2d8c-4ff8-af1c-044fa7973440
# Retrieved data for store id: 4d99a744-8087-44ff-b576-4bb0f6bb6ff4
# Retrieved data for store id: 769204f1-d8e4-41fb-8b9c-0b8b8f885376
# Waiting before processing the next batch...
# Retrieved data for store id: aa041099-fff7-42c5-bac8-c87a01f6f188
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 44...
# Number of stores in cluster: 12
# Retrieved data for store id: de063c86-ef9b-4ab0-a855-9cee522e02ba
# Retrieved data for store id: d5afe44f-91f5-45ff-9758-46c3ae29224b
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 3a92a1c7-823b-4716-a21a-675b88186bca
# Waiting before processing the next batch...
# Retrieved data for store id: 7f14a7b7-43da-4ed7-a2c2-69ae173e0d1f
# Retrieved data for store id: 24b395f7-c4af-4f27-963a-36a798c779f0
# Retrieved data for store id: 910841d7-8561-493c-a10e-6e2eae31f60a
# Retrieved data for store id: a431c9ff-1393-4b2f-84fd-0a849c8f0533
# Waiting before processing the next batch...
# Retrieved data for store id: b6e6b4d2-5883-4c02-8bc6-c4b70e446481
# Retrieved data for store id: ec4c1f0c-ea26-42e8-8a17-2e05f2f24b9e
# Retrieved data for store id: 9754b30c-e291-4557-9a98-b7c0052996cf
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 45...
# Number of stores in cluster: 12
# Retrieved data for store id: 42b34c0f-e768-4531-baba-cd0aebc2df16
# Retrieved data for store id: fe5e5373-808c-41de-8ef0-d3b0df42c49e
# Retrieved data for store id: 72eaa288-7edf-41ef-966f-065abbed0461
# Retrieved data for store id: 3ef9a93f-fe45-42b2-885e-69165ce44a03
# Waiting before processing the next batch...
# Retrieved data for store id: 0e7e2810-a62d-4cae-ac39-7938188cc0d6
# Retrieved data for store id: c49043ed-04eb-4b2a-b8a9-935da4c65bbf
# Retrieved data for store id: d3fe957d-8614-47a8-85a4-57423ca462ff
# Retrieved data for store id: fa8b4051-d9f8-4597-9f7a-32636996b859
# Waiting before processing the next batch...
# Retrieved data for store id: 2588314b-a1ce-478b-9b96-2c17225f784f
# Retrieved data for store id: 861b69ce-d460-48b6-b1cf-6ed827f506d7
# Retrieved data for store id: a7b81709-c9d9-4256-808c-3b827f0a47ae
# Retrieved data for store id: 02cbd823-f367-4ae4-8cdf-08fed15fb479
# Number of stores with no food waste data: 0
# Processing cluster 46...
# Number of stores in cluster: 6
# Retrieved data for store id: 0f5682ed-8f98-4ad5-af5c-52fe192e9b13
# Retrieved data for store id: 879d4ab6-ede6-4788-b21e-d5e2f5f6f0a7
# Retrieved data for store id: 3da7639a-8f73-4e41-ac5f-f5ebe5700adf
# Retrieved data for store id: 73c5514a-102f-4426-8ece-cbb42f9d1887
# Waiting before processing the next batch...
# Retrieved data for store id: 54620e2c-a34c-424e-83ff-36083a012603
# Retrieved data for store id: 8ce154b7-1e0b-46b6-8053-e256c7693760
# Number of stores with no food waste data: 0
# Processing cluster 48...
# Number of stores in cluster: 11
# Retrieved data for store id: c891c2a5-e302-4204-a7f5-8132ff5f5856
# Retrieved data for store id: cd348cf3-07ae-4af4-a321-d8e6382183b2
# Retrieved data for store id: edc497b9-5be3-40c8-b8bc-e70f1195b6d6
# Retrieved data for store id: 2453088a-9203-4176-8cd7-84a8365b7869
# Waiting before processing the next batch...
# Retrieved data for store id: 6fb3c05c-3941-42d6-bc8b-62d251153252
# Retrieved data for store id: 9f7a4856-1a13-45fd-906f-a324b9fe25b6
# Retrieved data for store id: 8b7eb697-d505-431f-ad89-835d324cf2e7
# Retrieved data for store id: 11e81965-a0dd-4c42-81b8-20ba9a173ff1
# Waiting before processing the next batch...
# Retrieved data for store id: 4db31bb1-04f9-4eec-b284-92832794e889
# Retrieved data for store id: 451116d7-397d-4751-b09d-fbbb35520065
# Retrieved data for store id: 42e25b24-1fda-4d28-82f8-5ceb532bda8e
# Number of stores with no food waste data: 0
# Processing cluster 50...
# Number of stores in cluster: 8
# Retrieved data for store id: 205be31d-de3d-4bf2-ab9e-27f638e31528
# Retrieved data for store id: 15c99a5c-e790-418b-9044-6f96ab17093f
# Retrieved data for store id: 6cdf90cb-f84c-480a-b49c-93f26c59b417
# Retrieved data for store id: 6408ed3e-5581-49aa-8ddd-9bfae159b020
# Waiting before processing the next batch...
# Retrieved data for store id: e91fb08c-e629-4229-82b2-aa77a1a744b7
# Retrieved data for store id: e2d0d855-02ee-4f51-858c-ca6022ca74c9
# Retrieved data for store id: 2588c255-65f6-41d0-afe9-251df11da414
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 52...
# Number of stores in cluster: 6
# Retrieved data for store id: d9e869ab-c63c-4218-9932-321d470b7428
# Retrieved data for store id: 0c43176d-96ab-4914-b66d-4c8b8f63f381
# Retrieved data for store id: 693666f6-6d9d-4ddd-ae26-9de84aadac57
# Retrieved data for store id: 43c0c172-437a-465f-8b17-c5adf3c2b93b
# Waiting before processing the next batch...
# Retrieved data for store id: 150f7992-2016-4075-a2f3-2a2f7c8ab7b2
# Retrieved data for store id: c73f2e63-1bd3-43a7-a0b7-b52f380f0e4e
# Number of stores with no food waste data: 0
# Processing cluster 58...
# Number of stores in cluster: 13
# Retrieved data for store id: b9b3c723-0aad-4341-b310-92e1974a2255
# Retrieved data for store id: 7fd81b2b-219b-4795-a561-c1a9d3fb28d1
# Retrieved data for store id: ac8f51b2-7ad0-4773-9363-8adfa58ced0d
# Retrieved data for store id: 69d79a53-0f02-47a3-9330-0286b04e7866
# Waiting before processing the next batch...
# Retrieved data for store id: f8b5d90b-0d95-4d4e-a56f-fffd5c7e7ff3
# Retrieved data for store id: decd8b10-dfc3-4082-90ed-2a219a52c8ca
# Retrieved data for store id: 70c07152-6cca-4fb6-a330-4398c8c24969
# Retrieved data for store id: 4f246472-6434-4ec1-9150-ba88270efb1b
# Waiting before processing the next batch...
# Retrieved data for store id: 9fe5e73e-dc8b-4a0f-9e6c-d7e921f46e3a
# Retrieved data for store id: 1ce49718-7226-4002-9006-4e1350220ef9
# Retrieved data for store id: 2d2abc82-d89b-48ea-a29c-37c27aa43a0b
# Retrieved data for store id: a3a67c23-1790-401b-9a80-31f02fd9aad5
# Waiting before processing the next batch...
# Retrieved data for store id: c03193c0-eadc-42a9-99e1-884f99dab48e
# Number of stores with no food waste data: 0
# Processing cluster 59...
# Number of stores in cluster: 12
# Retrieved data for store id: 7319551d-ed5e-4e6a-ae59-064758e0c5c2
# Retrieved data for store id: 4f9234e8-e054-4143-aa58-da4b389a1a75
# Retrieved data for store id: 6cb6a8b2-3a26-48ba-87dd-4c4c215c1b64
# Retrieved data for store id: a8f29c70-d427-4b30-b0e1-b0934fb0d5c7
# Waiting before processing the next batch...
# Retrieved data for store id: 2e7e4a1f-352b-4fdc-b4e4-8f4384e5a5d7
# Retrieved data for store id: 6ba6a678-77c9-4368-910f-b65c421ae59a
# Retrieved data for store id: 75bf0949-0fe2-4e83-8e85-e71d98844f0f
# Retrieved data for store id: 1d692e16-0ff9-4b3f-938e-1a755682fbcd
# Waiting before processing the next batch...
# Retrieved data for store id: b65534bf-4371-4210-8a06-6219fab96f80
# Retrieved data for store id: 7bde9d6f-8928-4eea-ba67-ac6c4ea5e8db
# Retrieved data for store id: 7ad81f8a-ed1f-4d77-b726-5742ce15fd9b
# Retrieved data for store id: c960d2b6-6f93-440f-93fc-64ecea6de7f3
# Number of stores with no food waste data: 0
# Processing cluster 60...
# Number of stores in cluster: 13
# Retrieved data for store id: e7f30e23-99b4-49ff-80d8-d14400969d09
# Retrieved data for store id: 77c394d6-c40e-43f4-a62e-46c6f1643274
# Retrieved data for store id: 379a8993-bcbe-40c2-ab6c-41abb7008569
# Retrieved data for store id: 0eb4352c-5ca4-4a09-a3f8-b77778bfa992
# Waiting before processing the next batch...
# Retrieved data for store id: 466a3feb-9c69-4b05-bf34-6117a0ea1212
# Retrieved data for store id: 6b0c387c-67b3-4a1f-bb5f-c63dfd9218a6
# Retrieved data for store id: 5e08422f-adaf-4109-bfd7-b36f3f6009d5
# Retrieved data for store id: 90fbc97f-35a8-4a24-a88f-a25451cf736b
# Waiting before processing the next batch...
# Retrieved data for store id: 9e4ab9b7-c816-4251-a1ae-76a2c2fe5c19
# Retrieved data for store id: eecd063f-307c-4be2-a3db-f7f311341bc8
# Retrieved data for store id: 048d6fed-fc65-40af-ab98-1510c478046d
# Retrieved data for store id: b9311150-a24e-4fa4-8d48-a6de93673f9f
# Waiting before processing the next batch...
# Retrieved data for store id: 69ce66a2-ad58-443e-a146-4a2d22382226
# Number of stores with no food waste data: 0
# Processing cluster 62...
# Number of stores in cluster: 6
# Retrieved data for store id: a160d429-5fe0-4818-8399-9a5b1e71d08c
# Retrieved data for store id: 7bc8e6d8-a520-4b24-82ea-af579ad181f1
# Retrieved data for store id: b08b8ebb-3163-452e-81a8-bb7c915f16b1
# Retrieved data for store id: 0f9675e4-2376-4677-908f-c5e9b4cff981
# Waiting before processing the next batch...
# Retrieved data for store id: 940943d4-393a-4aba-b931-5a5dadc319fe
# Retrieved data for store id: 88036bbd-d2ce-43c0-a99a-e30914175c08
# Number of stores with no food waste data: 0
# Processing cluster 63...
# Number of stores in cluster: 7
# Retrieved data for store id: 22bd40fd-4b80-4630-b25e-243dbe5784cf
# Retrieved data for store id: 83c0b980-fb7b-4cb0-a76d-0109f533b164
# Retrieved data for store id: 53653850-91e9-4ce0-903b-13d0509dff06
# Retrieved data for store id: 2f69ff57-66f6-4fa8-bf11-6a9e4db571a5
# Waiting before processing the next batch...
# Retrieved data for store id: be3b2418-cdf6-4131-bd50-a187bff83ea7
# Retrieved data for store id: 8a16987a-d80f-48b6-9ce1-5e480136ccfd
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 64...
# Number of stores in cluster: 15
# Retrieved data for store id: 78067122-cba4-431d-893e-2b2c0c91e41e
# Retrieved data for store id: e1ed4932-4bef-4220-ac59-211b3b561e57
# Retrieved data for store id: 3e1414f5-45f4-45cc-8c4f-80b49c6386e1
# Retrieved data for store id: 4e58930a-3188-43c8-8078-87def1aabb5c
# Waiting before processing the next batch...
# Retrieved data for store id: 01bb056b-d7e6-4892-85a8-10dc984581f5
# Retrieved data for store id: 63765d8a-71a2-45a7-b1ce-a63b8cec8ed1
# Retrieved data for store id: c41aaac9-b98d-4eee-a898-83226db622ff
# Retrieved data for store id: 9a6b138c-36cc-469d-93da-c146cd8a5cbf
# Waiting before processing the next batch...
# Retrieved data for store id: 5430c265-d03b-4b30-856d-3ec74966df52
# Retrieved data for store id: 1c9d1304-26c5-4f29-903c-81912161df99
# Retrieved data for store id: aa777e4b-5ac8-41b1-8da3-c2f6096e16e6
# Retrieved data for store id: 5ebb4f99-7125-470e-9e31-a638b1b65af2
# Waiting before processing the next batch...
# Retrieved data for store id: 7a32fc91-9235-4441-84e6-4f28e2817a61
# Retrieved data for store id: c9c2d918-077a-4583-8040-a611c3c8a024
# Retrieved data for store id: 3e24cf0b-e754-4eb4-b8f1-2505f6d9f3e8
# Number of stores with no food waste data: 0
# Processing cluster 66...
# Number of stores in cluster: 9
# Retrieved data for store id: 43fc5dfe-cbe3-4c5c-b401-5a6a70c98c80
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 856c06a6-c1b9-47a8-ba85-a8ce13221119
# Retrieved data for store id: 81ecf729-d8e7-47b7-876f-c314e13f386e
# Waiting before processing the next batch...
# Retrieved data for store id: 3bb5b0b9-3ebc-44b0-9189-c99b3560b3ee
# Retrieved data for store id: 2e250028-4bcf-4fc4-9618-0dcb45b47c2e
# Retrieved data for store id: 32bb4a1e-a546-4ab1-b803-4cd95c2fe801
# Retrieved data for store id: c9d2f4d0-758e-4b92-9d1d-8250f626264c
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 67...
# Number of stores in cluster: 7
# Retrieved data for store id: d56bb3cd-056d-40e1-ae5c-0f6de05e5cbd
# Retrieved data for store id: c35f55dd-2c1c-4848-8196-556dd1870759
# Retrieved data for store id: 1a909014-27d6-47c3-9e04-c5944897057d
# Retrieved data for store id: 968c4f55-7b56-4a20-ac08-d6be9706985a
# Waiting before processing the next batch...
# Retrieved data for store id: 31771d71-6522-4443-9cff-1807f5d155bc
# Retrieved data for store id: 3760433c-e3e1-4991-b8ed-c81012b51fd0
# Retrieved data for store id: f610a550-6089-49a4-b145-1eb7c496fc27
# Number of stores with no food waste data: 0
# Processing cluster 69...
# Number of stores in cluster: 6
# Retrieved data for store id: dcf77403-e5af-4257-ba68-4d6b07d77f41
# Retrieved data for store id: 6e00370c-0def-45d8-a6d4-51852f1a5885
# Retrieved data for store id: c8260737-ef28-4075-a4fb-e67afcbf18fb
# Retrieved data for store id: d7642f0b-8fdb-4794-bdda-e9d36d4b7c66
# Waiting before processing the next batch...
# Retrieved data for store id: a5c45178-d2a9-4df4-8df0-b32371904468
# Retrieved data for store id: 106d3265-7e67-4931-8638-d0c18b719b2f
# Number of stores with no food waste data: 0
# Processing cluster 73...
# Number of stores in cluster: 11
# Failed to retrieve data. Status code: 400
# Retrieved data for store id: 43c8b72b-fc30-4030-b0eb-05ce6e74e14c
# Retrieved data for store id: 57f10317-69cb-43b1-80f9-1a46d705c21f
# Retrieved data for store id: 683d62ae-1aae-4878-b345-b99ec5cdf541
# Waiting before processing the next batch...
# Retrieved data for store id: d34f8611-d877-4789-bfc0-d9ba24f871c7
# Retrieved data for store id: 02ac52b2-0d37-430e-8284-e950bdda7a0f
# Retrieved data for store id: d023430c-a247-4d90-9f61-b05ee17eeb3a
# Retrieved data for store id: 458faa1d-3692-47ee-98b8-8217c9539ee4
# Waiting before processing the next batch...
# Retrieved data for store id: 8687eb83-88d0-4e7e-a87d-5d2297ad00ec
# Retrieved data for store id: abc74dcc-1696-4e94-bcef-d00c44fb58a9
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 2
# Processing cluster 75...
# Number of stores in cluster: 7
# Retrieved data for store id: b4ab6bf0-1a21-46c1-ba29-ae16aec1eb87
# Retrieved data for store id: 50879c5b-e7f0-41a9-83ca-02167f2e03b0
# Retrieved data for store id: a621be50-cfac-4397-8afc-c96349c01720
# Retrieved data for store id: b736a5b1-ae86-4484-a056-46f0784d6ac7
# Waiting before processing the next batch...
# Retrieved data for store id: 3e029c56-e57a-47d2-b054-eb14292b4665
# Retrieved data for store id: 96420a8f-6a70-4206-9e5e-a7b27716ac1c
# Retrieved data for store id: 74cc337b-f695-4fcf-8301-1f61d055ff58
# Number of stores with no food waste data: 0
# Processing cluster 76...
# Number of stores in cluster: 8
# Retrieved data for store id: aa767d71-1b66-4a12-be82-97430aa9f762
# Retrieved data for store id: 6a6595b8-eacc-4c5b-a1e3-6d3bad51b609
# Retrieved data for store id: 92dfabc5-2fe3-4d6d-aea4-1cfd90d671cb
# Retrieved data for store id: afe072a2-4809-4c99-95e0-7e79b6283374
# Waiting before processing the next batch...
# Retrieved data for store id: 2b2a046f-1454-4db5-89db-251f63775a9e
# Retrieved data for store id: 7d838e6b-d26a-49a5-bf33-177546c5ef55
# Retrieved data for store id: c77c8567-eeff-4279-8006-7bec6b730b59
# Retrieved data for store id: 501fd2ae-d570-4db3-91de-b87048623c25
# Number of stores with no food waste data: 0
# Processing cluster 77...
# Number of stores in cluster: 9
# Retrieved data for store id: 64fb6423-57b0-457c-a054-8a024a2d86b8
# Retrieved data for store id: bef5a9f8-9ac5-4817-9899-3123fcbe4acf
# Retrieved data for store id: 30b85210-354e-4eb5-927b-70926adbdb49
# Retrieved data for store id: 30c80533-e12f-493a-800e-254e79e97e9d
# Waiting before processing the next batch...
# Retrieved data for store id: db00f1e7-7245-4d6b-b4ca-579a697e2d9f
# Retrieved data for store id: 31e281af-cbf0-4131-8957-843997b8b15f
# Retrieved data for store id: a9bb534a-28f6-45d4-b201-b20efa4909dc
# Retrieved data for store id: f652c6a3-c025-4ca2-b152-081845745be1
# Waiting before processing the next batch...
# Failed to retrieve data. Status code: 400
# Number of stores with no food waste data: 1
# Processing cluster 84...
# Number of stores in cluster: 5
# Retrieved data for store id: c1e80e96-7d3e-4baa-a996-d4fcb1c519e9
# Retrieved data for store id: e005b409-9ea7-4506-a444-07f419b6ee5e
# Retrieved data for store id: 8daddc4d-1d4b-4f02-972b-ccab39440062
# Retrieved data for store id: 594ead4a-ef86-4b34-baa1-6bb8b0bbd880
# Waiting before processing the next batch...
# Retrieved data for store id: 92fea766-a547-429d-bd67-1b74dcc0ef76
# Number of stores with no food waste data: 0
# Processing cluster 111...
# Number of stores in cluster: 6
# Retrieved data for store id: 625cd0d4-53a6-4cac-90df-211341f1546e
# Retrieved data for store id: 655ea375-e01d-45e4-8344-73d3c670cad9
# Retrieved data for store id: dca50891-be2a-4211-a1c5-89ca84111e0f
# Retrieved data for store id: 357ed080-483f-4ed3-a175-8144e0067ef2
# Waiting before processing the next batch...
# Retrieved data for store id: 0ebcbc68-ebbc-4b8b-90b0-5c99bfb714cf
# Retrieved data for store id: 526310e8-0dc6-4c38-93e4-4d939d469855
# Number of stores with no food waste data: 0
# Data processing completed.

# %%
#print the quality of the data
clusters_quality_df = pd.DataFrame(clusters_quality).T
clusters_quality_df['Total Stores'] = clusters_df['Number of Stores']
clusters_quality_df['Quality'] = clusters_quality_df['No. Stores with Food Waste'] / clusters_quality_df['Total Stores']
clusters_quality_df
# Out:
#      No. Stores with Food Waste  No. Stores without Food Waste  Total Stores  \
# 0                             5                              2           7.0
# 1                             6                              3           9.0
# 2                             8                              2          10.0
# 3                             8                              3          11.0
# 4                             6                              0           6.0
# 5                             7                              2           9.0
# 6                             6                              3           9.0
# 7                             4                              2           6.0
# 8                             9                              1          10.0
# 10                            8                              3           7.0
# 11                            6                              1          13.0
# 12                           12                              1           9.0
# 13                            7                              2           6.0
# 14                            4                              2           6.0
# 15                            5                              1           6.0
# 16                            5                              1           5.0
# 18                            4                              1           9.0
# 19                           11                              4          12.0
# 20                            6                              3           7.0
# 23                            8                              4          13.0
# 24                            5                              2          12.0
# 28                           11                              0           8.0
# 31                            8                              0           6.0
# 32                           12                              1           6.0
# 33                            9                              3          12.0
# 35                            7                              0           6.0
# 36                            4                              1          11.0
# 37                            7                              0           8.0
# 38                            8                              0           6.0
# 39                            6                              0          13.0
# 41                           10                              0          13.0
# 42                            6                              0           6.0
# 43                            5                              1           7.0
# 44                           10                              2          15.0
# 45                           12                              0           9.0
# 46                            6                              0           7.0
# 48                           11                              0          11.0
# 50                            7                              1           8.0
# 52                            6                              0           5.0
# 58                           13                              0           NaN
# 59                           12                              0           NaN
# 60                           13                              0           NaN
# 62                            6                              0           NaN
# 63                            6                              1           NaN
# 64                           15                              0           NaN
# 66                            7                              2           NaN
# 67                            7                              0           NaN
# 69                            6                              0           NaN
# 73                            9                              2           NaN
# 75                            7                              0           NaN
# 76                            8                              0           NaN
# 77                            8                              1           NaN
# 84                            5                              0           NaN
# 111                           6                              0           NaN
#
#       Quality
# 0    0.714286
# 1    0.666667
# 2    0.800000
# 3    0.727273
# 4    1.000000
# 5    0.777778
# 6    0.666667
# 7    0.666667
# 8    0.900000
# 10   1.142857
# 11   0.461538
# 12   1.333333
# 13   1.166667
# 14   0.666667
# 15   0.833333
# 16   1.000000
# 18   0.444444
# 19   0.916667
# 20   0.857143
# 23   0.615385
# 24   0.416667
# 28   1.375000
# 31   1.333333
# 32   2.000000
# 33   0.750000
# 35   1.166667
# 36   0.363636
# 37   0.875000
# 38   1.333333
# 39   0.461538
# 41   0.769231
# 42   1.000000
# 43   0.714286
# 44   0.666667
# 45   1.333333
# 46   0.857143
# 48   1.000000
# 50   0.875000
# 52   1.200000
# 58        NaN
# 59        NaN
# 60        NaN
# 62        NaN
# 63        NaN
# 64        NaN
# 66        NaN
# 67        NaN
# 69        NaN
# 73        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 84        NaN
# 111       NaN

# %%
import pickle

# Save the dictionary to a pickle file
with open('data/salling_data_bf_cleaning.pkl', 'wb') as f:
    pickle.dump(salling_data, f)

# %%
# List to hold DataFrames with cluster number
dfs_with_cluster = []

# Iterate through the dictionary
for cluster_id, df in salling_data.items():
    # Add a column for the cluster number
    df['cluster_id'] = cluster_id
    # Append the DataFrame to the list
    dfs_with_cluster.append(df)

# Concatenate all DataFrames into a single DataFrame
all_products_df = pd.concat(dfs_with_cluster, ignore_index=True)

# Display the resulting DataFrame
all_products_df.tail(10)
# Out:
#                                    Store id      Store Name Store Address  \
# 12587  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12588  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12589  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12590  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12591  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12592  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12593  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12594  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12595  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
# 12596  526310e8-0dc6-4c38-93e4-4d939d469855  Netto Bellinge   Bronzevej 1
#
#       Store City Store Zip Store Brand                     Description  \
# 12587  Odense Sv      5250       netto                     SYLTE LAMPE
# 12588  Odense Sv      5250       netto                   MINI 20+ THEM
# 12589  Odense Sv      5250       netto  OKSEPØLSER M/BAC.OST LØGISMOSE
# 12590  Odense Sv      5250       netto   GRILLPØLSER M/URTER LØGISMOSE
# 12591  Odense Sv      5250       netto       PARTYP#LSER P#LSEMESTEREN
# 12592  Odense Sv      5250       netto    GROVHAK. LEVERPOSTEJ STRYHNS
# 12593  Odense Sv      5250       netto           PESTO ROSSO LØGISMOSE
# 12594  Odense Sv      5250       netto               SPARERIBS JENSENS
# 12595  Odense Sv      5250       netto       SKYR M/ MANGO LIME CHEASY
# 12596  Odense Sv      5250       netto     DANBO SKIVER MK ML EGELYKKE
#
#                  EAN                                    Categories (da)  \
# 12587  5703603010319              Mejeri & køl>Pålæg>Leverpostej & paté
# 12588  5707673109461                   Mejeri & køl>Mejeri>Ost>Skæreost
# 12589  5712876193032  Mejeri & køl>Bacon, pølser & toppings>Pølser>O...
# 12590  5712876193056  Mejeri & køl>Bacon, pølser & toppings>Pølser>G...
# 12591  5712875552601  Mejeri & køl>Bacon, pølser & toppings>Pølser>G...
# 12592  5704000502391              Mejeri & køl>Pålæg>Leverpostej & paté
# 12593  5701924361752  Mejeri & køl>Tapas & specialiteter>Pesto & hummus
# 12594  5745000172771                 Kød & fisk>Spareribs & barbecuekød
# 12595  5711953172199  Mejeri & køl>Mejeri>Yoghurt & syrnede mælkepro...
# 12596  5711953100154               Mejeri & køl>Mejeri>Ost>Ost i skiver
#
#                                          Categories (en)  ... Currency  \
# 12587  Dairy And Cold Storage>Lunch Meats>Liver Paste...  ...      DKK
# 12588  Dairy And Cold Storage>Dairy>Cheese>Cheese For...  ...      DKK
# 12589  Dairy And Cold Storage>Bacon Sausages Toppings...  ...      DKK
# 12590  Dairy And Cold Storage>Bacon Sausages Toppings...  ...      DKK
# 12591  Dairy And Cold Storage>Bacon Sausages Toppings...  ...      DKK
# 12592  Dairy And Cold Storage>Lunch Meats>Liver Paste...  ...      DKK
# 12593  Dairy And Cold Storage>Tapas Specialities>Pest...  ...      DKK
# 12594                  Meat Fish>spareribs Barbecue Meat  ...      DKK
# 12595  Dairy And Cold Storage>Dairy>Yoghurt Soured Mi...  ...      DKK
# 12596  Dairy And Cold Storage>Dairy>Cheese>Sliced Cheese  ...      DKK
#
#       Original Price New Price Discount Percent Discount  \
# 12587          38.95      10.0    28.95            74.33
# 12588          54.95      10.0    44.95            81.80
# 12589          39.95      24.0    15.95            39.92
# 12590          39.95      24.0    15.95            39.92
# 12591          25.25      19.0     6.25            24.75
# 12592          29.95       9.0    20.95            69.95
# 12593          21.95       4.0    17.95            81.78
# 12594          45.00      35.0    10.00            22.22
# 12595          32.95      10.0    22.95            69.65
# 12596          31.95      18.0    13.95            43.66
#
#                      Start Time                  End Time  Stock  Stock Unit  \
# 12587  2024-11-24T12:49:19.000Z  2024-11-24T22:59:59.000Z    4.0        each
# 12588  2024-11-24T12:52:41.000Z  2024-11-24T22:59:59.000Z   11.0        each
# 12589  2024-11-24T11:38:14.000Z  2024-11-25T22:59:59.000Z   15.0        each
# 12590  2024-11-24T11:39:37.000Z  2024-11-25T22:59:59.000Z   12.0        each
# 12591  2024-11-21T06:10:35.000Z  2024-11-26T22:59:59.000Z    3.0        each
# 12592  2024-11-24T12:47:12.000Z  2024-11-24T22:59:59.000Z    2.0        each
# 12593  2024-11-24T12:47:27.000Z  2024-11-24T22:59:59.000Z    1.0        each
# 12594  2024-11-24T05:41:35.000Z  2024-11-27T22:59:59.000Z   16.0        each
# 12595  2024-11-24T12:51:53.000Z  2024-11-24T22:59:59.000Z    2.0        each
# 12596  2024-11-24T12:56:14.000Z  2024-11-26T22:59:59.000Z   56.0        each
#
#        cluster_id
# 12587         111
# 12588         111
# 12589         111
# 12590         111
# 12591         111
# 12592         111
# 12593         111
# 12594         111
# 12595         111
# 12596         111
#
# [10 rows x 25 columns]

# %%
# count number of products per store name for the first cluster
all_products_df[all_products_df['cluster_id'] == 0]['Store Name'].value_counts()
# Out:
# Store Name
# Bilka Tilst        70
# Netto Brabrand     40
# Netto Viborgvej    22
# Netto Tilst        20
# Name: count, dtype: int64

# %%
all_products_df[['Store Name', 'Category 1', 'Category 2', 'Category 3', 'Category 4', 'Description', 'Percent Discount', 'Original Price', 'New Price']].head()
# Out:
#     Store Name                  Category 1                 Category 2  \
# 0  Bilka Tilst                Dinner Meals         Ready To Eat Meals
# 1  Bilka Tilst                Roasted Pork  Roasted Whole Pork Pieces
# 2  Bilka Tilst                  Other Pork                       Pork
# 3  Bilka Tilst  Pork Chops Pork Schnitzels                       Pork
# 4  Bilka Tilst                      Salami                       Meat
#
#                Category 3              Category 4  \
# 0  Dairy And Cold Storage                    None
# 1                    Pork               Meat Fish
# 2               Meat Fish                    None
# 3               Meat Fish                    None
# 4             Lunch Meats  Dairy And Cold Storage
#
#                    Description  Percent Discount  Original Price  New Price
# 0                 GODT BEGYNDT             19.19           99.00      80.00
# 1       PORCHETTA SLGATERMESTE             63.09          149.00      55.00
# 2         SYLTEPAKKE SLAGTEREN             44.94           89.00      49.00
# 3  SKAFTEKOTELETTE BETJENTDISK             60.04          135.00      53.95
# 4         KÅLPØLSE PØLSEMAGERI             19.92           49.95      40.00

# %%
# list of all distinct values in category 1
all_products_df['Category 1'].unique()
# Out:
# array(['Dinner Meals', 'Roasted Pork', 'Other Pork',
#        'Pork Chops Pork Schnitzels', 'Salami', 'Pork Neck Pork Loin',
#        'Thick Sausages', 'Pork Sausages', 'Liver Paste Patee',
#        'Cold Cuts Turkey', 'Corned Beef', 'Cold Cuts Chicken',
#        'Cheese Specialities', 'Seeded Rye Breads',
#        'Cold Coffee Drinks Cacao', 'Fish Mayo Salads', 'Pancakes',
#        'Sausage Roll', 'Olives Other Attachments', 'Other Mayo Salads',
#        'Roastbeef', 'Pesto Hummus', 'Toast Breads', 'Whole Milk',
#        'Nonfat Milk', 'Skimmed Milk', 'Cold Cuts Ham', 'Sliced Cheese',
#        'Sliced Lunch Meats', 'Cold Cuts Specialities',
#        'Sausages Specialities', 'Minced Pork', 'Light Dark Buns',
#        'Rye Breads With Carrots', 'Minced Pork Veal', 'Meat Sausage',
#        'Sun Flower Seeded Rye Breads', 'Crisp Bread', 'Skyr',
#        'Buttermilk', 'Ready To Eat Meat Alternatives', 'Other Rye Breads',
#        'Prepared Potatoes', 'Yoghurt', 'Fresh Pasta Without Fillings',
#        'Desserts Snacks', 'Cheese For Slicing', 'Pork Tenderloin', 'Lamb',
#        'Ready To Eat Soups', 'Beef Sausages', 'spareribs Barbecue Meat',
#        'Whole Breads', 'Rice Crackers Corn Crackers',
#        'Plant Based Milk Alternatives', 'Butter', 'Cottage Cheese',
#        'Frozen Pork', 'Sandwiches Wraps', 'Naan Breads Flat Breads',
#        'Burger Buns', 'Smoked Saddle Of Pork',
#        'Plant Based Cream Alternatives', 'Hotdog Buns', 'Cream Cheese',
#        'Minced Beef', 'Cold Butter Milk Soup', 'Semiskimmed Milk',
#        'Margarine', 'Drinking Yoghurt Kids Yoghurt',
#        'Creme Fraiche Quark', 'Smoothies', 'Meat Balls', 'Soured Milk',
#        'Pita Bread', 'Sliced Bacon', 'Mozarella',
#        'Plant Based Yoghurt Alternatives', 'Sauce', 'Protein Shake',
#        'Other Butters', 'Chicken Sausages', 'Blue Cheese Brie',
#        'Prepared Chicken', 'Dressings', 'Plant Based Toppings',
#        'Whipping Cream', 'Cocktail Sausages Brunch Sausages',
#        'Poultry Mayo Salads', 'fresh Dough', 'Chopped Bacon Bits',
#        'Multi Fruit Juices', 'Whole Grain Crackers', 'Pork Mayo Salads',
#        'Dinner Salads', 'Salted Crackers', 'Salat Cheese',
#        'Roasted Whole Beef Pieces', 'potato Salad', 'Apple Juices',
#        'Cream Potatoes', 'Cooking Cream', 'Ready To Eat Pizza',
#        'Snack Cheese', 'Other Toppings', 'Shredded Cheese Toppings',
#        'Orange Juices', 'Chopped Pork', 'Yeast', 'Fats',
#        'Italian Mayo Salads', 'Other Fruit Juices',
#        'Special Whole Breads', 'Prepared Pizza Base', 'Other Ready Meals',
#        'Chocolate Crackers Sweet Crackers', 'Fruit Shots Vegetable Shots',
#        'Coffee Cream', 'Sport Drinks', 'Meat Alternatives', 'Chopped Ham',
#        'Tapenades', 'Grilled Cheese', 'Croutons Breadsticks',
#        'Remoulade Mayonnaise', 'Rusks', 'Bacon Whole Pieces', 'Tartlets'],
#       dtype=object)

# %% [markdown]
# It is visible that some of the ingredients are not in the most simple form of ingredients, so we will have to clean the data and make it more simple

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize


# Initialize NLTK tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# List of irrelevant words to remove
irrelevant_words = ['prepared', 'fresh', 'ready', 'to', 'eat', 'other', 'specialities', 'without', 'fillings', 'based', 'alternatives']

# Function to clean and filter ingredients
def clean_ingredients(data):
    cleaned_ingredients = []
    for ingredient in data['Category 1']:
        words = word_tokenize(ingredient.lower())
        # Tag parts of speech
        pos_tags = nltk.pos_tag(words)
        # Filter out verbs and irrelevant words
        filtered_words = [lemmatizer.lemmatize(word) for word, pos in pos_tags if pos[0] != 'V' and word not in stop_words and word not in irrelevant_words]
        cleaned_ingredient = ' '.join(filtered_words)
        cleaned_ingredients.append(cleaned_ingredient)
    return cleaned_ingredients

# Clean the ingredients
cleaned_ingredients = clean_ingredients(all_products_df)

# %%
# Create a DataFrame with the original and cleaned ingredients
check_clean_up = pd.DataFrame({
    'Original Ingredients': all_products_df['Category 1'],
    'Cleaned Ingredients': cleaned_ingredients
})

# Display the unique values of the specified columns
unique_values = check_clean_up[['Original Ingredients', 'Cleaned Ingredients']].drop_duplicates()

print(unique_values)
# Out:
#              Original Ingredients       Cleaned Ingredients
# 0                    Dinner Meals               dinner meal
# 1                    Roasted Pork                      pork
# 2                      Other Pork                      pork
# 3      Pork Chops Pork Schnitzels  pork chop pork schnitzel
# 4                          Salami                    salami
# ...                           ...                       ...
# 6982         Croutons Breadsticks        crouton breadstick
# 7234         Remoulade Mayonnaise      remoulade mayonnaise
# 7894                        Rusks                      rusk
# 8019           Bacon Whole Pieces         bacon whole piece
# 11032                    Tartlets                   tartlet
#
# [128 rows x 2 columns]

# %%
# i want to change the ingreddients for the cleaned ones
all_products_df['Cleaned Ingredients'] = cleaned_ingredients

# %%
# i want to save the data frame they have special caracters that are not supported by csv
# so i will save it as a pickle file
all_products_df.to_pickle('data/salling_data.pkl')

# %% [markdown]
# ## Understanding Data

# %% [markdown]
# We will dive into some exploratory analyses to better understand how the data is organized, what the most influential products are in the data set, and whether there are any relationships or trends among stores.

# %% [markdown]
# Let's count the number of distinct categories at each level:

# %%
# import the data
salling_data = pd.read_pickle('data/salling_data.pkl')

# %%
# Count number of distinct categories 1,2,3,4
cat1_unique = salling_data['Category 1'].nunique()
cat2_unique = salling_data['Category 2'].nunique()
cat3_unique = salling_data['Category 3'].nunique()
cat4_unique = salling_data['Category 4'].nunique()

# Print the results
print(f"Number of unique values in 'Category 1': {cat1_unique}")
print(f"Number of unique values in 'Category 2': {cat2_unique}")
print(f"Number of unique values in 'Category 3': {cat3_unique}")
print(f"Number of unique values in 'Category 4': {cat4_unique}")
# Out:
# Number of unique values in 'Category 1': 128
# Number of unique values in 'Category 2': 35
# Number of unique values in 'Category 3': 13
# Number of unique values in 'Category 4': 14

# %% [markdown]
# Since this data is quite dynamic, changing daily depending on the stock of previous products and the incorporation of new ones, it is difficult to analyze/categorize with none static data.

# %%
#min start time and max end time
salling_data['Start Time'] = pd.to_datetime(salling_data['Start Time'])
salling_data['End Time'] = pd.to_datetime(salling_data['End Time'])

print("Min start time:", salling_data['Start Time'].min())
print("Max start time:", salling_data['Start Time'].max())
print("Max end time:", salling_data['End Time'].max())
# Out:
# Min start time: 2024-09-30 12:41:27+00:00
# Max start time: 2024-11-24 13:49:48+00:00
# Max end time: 2025-01-23 22:59:59+00:00

# %%
# plot of quantity of products per start day
salling_data['Start Time'].dt.date.value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.title('Quantity of Products per Day')
# Out:
# Text(0.5, 1.0, 'Quantity of Products per Day')

# %% [markdown]
# As expected, the closer we get to today’s date, the higher the number of products.

# %%
#quantity of products per store
salling_data['Store Name'].value_counts().plot(kind='bar', figsize=(12, 6))
plt.title('Quantity of Products per Store')
# Out:
# Text(0.5, 1.0, 'Quantity of Products per Store')

# %% [markdown]
# The most frequent ingredients are bread, ready-to-eat meals, and cheese, which is expected given the shelf life of these types of products.

# %%
# plot the ingredients and their counts
salling_data['Category 2'].value_counts().plot(kind='bar', color='blue');

# %%
# Count the occurrences of each category in 'Category 1'
category_counts = salling_data['Category 1'].value_counts()

# Get the top 20 categories
top_20_cat1 = category_counts.head(20).index

# Filter the original data to include only the top 20 categories in 'Category 1'
top_20_data = salling_data[salling_data['Category 1'].isin(top_20_cat1)]

# Now group by all three categories to get the flow from Category 1 to Category 2 to Category 3
grouped_data = top_20_data.groupby(['Category 1', 'Category 2', 'Category 3']).size().reset_index(name='Count')

# Create the source, target, and value lists for the Sankey diagram
sources = []
targets = []
values = []

# Map each category to a unique index
label_to_id = {label: idx for idx, label in enumerate(pd.concat([grouped_data['Category 1'], grouped_data['Category 2'], grouped_data['Category 3']]).unique())}

for i, row in grouped_data.iterrows():
    sources.append(label_to_id[row['Category 1']])
    targets.append(label_to_id[row['Category 2']])
    values.append(row['Count'])

    # Include the second link if Category 3 is present
    if pd.notnull(row['Category 3']):
        sources.append(label_to_id[row['Category 2']])
        targets.append(label_to_id[row['Category 3']])
        values.append(row['Count'])

# Define colors for each category level
colors = ['rgba(31, 119, 180, 0.8)', 'rgba(255, 127, 14, 0.8)', 'rgba(44, 160, 44, 0.8)']

# Create a color list for the nodes
node_colors = [colors[0] if label in top_20_cat1 else colors[1] if label in grouped_data['Category 2'].unique() else colors[2] for label in label_to_id]

# Create the Sankey diagram
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        label=[label for label in label_to_id],
        color=node_colors  # Set different colors for each category level
    ),
    link=dict(
        source=sources,
        target=targets,
        value=values,
        color='rgba(50, 50, 50, 0.3)'  # Links in gray for contrast
    )
)])

# Update layout
fig.update_layout(title_text='Sankey Diagram for Top 20 "Category 1" Categories', font_size=12)

# Display the Sankey diagram
fig.show()

# %% [markdown]
# Using a Sankey diagram for the distribution of the top 20 most populated categories from Category 1 (blue), we can see how they are grouped into Category 2 (orange) and Category 3 (green). It is evident, for example, that 'Lunch Meats' can appear in both Category 2 and 3. This occurs because the category description column is divided into several sections of varying sizes, allowing some products to have a more detailed grouping than others. We can clearly see that the majority of products in the last column with green color are bread and cakes.

# %% [markdown]
# We can also see which stores offer better deals and discounts.

# %%
# Group the discounts in 4 bins from 0-25, 25-50, 50-75, 75-100 and count how many items per store are in those bins
salling_data['Discount Bins'] = pd.cut(salling_data['Percent Discount'], bins=[0, 25, 50, 75, 100])

# Group by store and discount bins, and count the number of items
discount_bins_per_store = salling_data.groupby(['Store Name', 'Discount Bins']).size().unstack()

# Calculate the total number of items per store
discount_bins_per_store['Total'] = discount_bins_per_store.sum(axis=1)

# Sort the stores by the total number of items in descending order
discount_bins_per_store = discount_bins_per_store.sort_values(by='Total', ascending=False)

# Drop the total column
discount_bins_per_store = discount_bins_per_store.drop(columns='Total')

# Plot the result
discount_bins_per_store.plot(kind='bar', stacked=True)
plt.title('Discount Bins per Store')
plt.show()
# Out:
# C:\Users\luicor\AppData\Local\Temp\ipykernel_46372\3548486503.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# It is visible that for all stores, the majority of the products have a discount between 25-50%.

# %% [markdown]
# Let's see if the most discounted products are the ones that have been in the store for a longer time.

# %%
# Convert 'Start Time' to date
salling_data['Start Date'] = pd.to_datetime(salling_data['Start Time']).dt.date

# 4 bins discount per start date
salling_data['Discount Bins'] = pd.cut(salling_data['Percent Discount'], bins=[0, 25, 50, 75, 100])
discount_bins_per_start_date = salling_data.groupby(['Start Date', 'Discount Bins']).size().unstack()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot the counts
discount_bins_per_start_date.plot(kind='bar', stacked=True, ax=axes[0])
axes[0].set_title('Counts')

# Normalize the counts to get percentages
discount_bins_per_start_date_percentage = discount_bins_per_start_date.div(discount_bins_per_start_date.sum(axis=1), axis=0)

# Plot the percentages
discount_bins_per_start_date_percentage.plot(kind='bar', stacked=True, ax=axes[1])
axes[1].set_title('Percentages')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\luicor\AppData\Local\Temp\ipykernel_46372\2601114005.py:6: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# Given the graphs and the data that we have, there is no clear evidence that older products are more discounted than recent ones. Additionally, since the data is static, we cannot investigate if the product discounts change over time.

# %% [markdown]
# We can also visualize the types of products that receive the most discounts and the percentage of discounts per category.

# %%
# top 10 products with the highest discount and respective category 2
top_10_discounts = salling_data.nlargest(10, 'Percent Discount')
top_10_discounts[['Description', 'Percent Discount', 'Original Price', 'New Price', 'Category 2', 'Store Name']]
# Out:
#                     Description  Percent Discount  Original Price  New Price  \
# 10568       KERNEGROV LEVEBRØD.             92.00           25.00       2.00
# 10547   GROV SANDWICH SCHULSTAD             91.98           24.95       2.00
# 1082     SAMSØ SKÆREOST SALLING             91.74           59.95       4.95
# 10587             FLADBRØD LIBA             90.87           10.95       1.00
# 211       HYTTEOST 4% KAROLINES             89.09           27.50       3.00
# 7630   SVINEMØRBRAD SALLING ØKO             88.76           89.00      10.00
# 8044      SILK. KYLLING SALLING             88.20           16.95       2.00
# 2650            SALTKØD SALLING             86.51           14.83       2.00
# 9176     5-KORNS BRØD SCHULSTAD             85.71           28.00       4.00
# 2684   KERNEGLØD RUGBR LEVEBRØD             85.69           27.95       4.00
#
#                       Category 2                  Store Name
# 10568                 Rye Breads              føtex Kokkedal
# 10547   Light Breads Dark Breads              føtex Kokkedal
# 1082                      Cheese                 Bilka Ishøj
# 10587         Bread Specialities              føtex Kokkedal
# 211                       Cheese              Bilka Skalborg
# 7630   Roasted Whole Pork Pieces                føtex Herlev
# 8044                        Meat             føtex Ro's Torv
# 2650                        Meat               Bilka Horsens
# 9176    Light Breads Dark Breads        føtex Lautrupcentret
# 2684                  Rye Breads  føtex Horsens, Bankagervej

# %%
# Group by 'EAN' and find out if there are multiple unique prices for each EAN
ean_price = salling_data.groupby('EAN')['Original Price'].nunique()

# Get EANs with more than one unique price across stores
ean_with_diff_price = ean_price[ean_price > 1].index

# Pivot the table to see prices per store for each EAN
ean_price_per_store = salling_data.pivot_table(index='EAN', columns='Store Name', values='Original Price', aggfunc=np.mean)


# Calculate the average price for each EAN
ean_avg_price = ean_price_per_store.mean(axis=1)

# Normalize prices by subtracting the average price of each EAN from its prices across stores
normalized_prices = ean_price_per_store.sub(ean_avg_price, axis=0)

# Now, let's visualize this with a heatmap, where color indicates deviation from the average price
plt.figure(figsize=(12, 10))
sns.heatmap(normalized_prices.loc[ean_with_diff_price], cmap='coolwarm', center=0)
plt.title('Heatmap of Price Differences per EAN Across Stores')
plt.show()
# Out:
# C:\Users\luicor\AppData\Local\Temp\ipykernel_46372\1607095920.py:8: FutureWarning:
#
# The provided callable <function mean at 0x0000025872F0EE80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.

# %% [markdown]
# There are a few cases where supermarkets might have local pricing, resulting in different prices for the same EAN among stores. However, these cases are not frequent, as is visible in the table above.

# %% [markdown]
# To better understand the discount rules, we can also check whether the discounts are consistent across the same products.

# %%
# Check if for the same ean if they have the same discount in all stores
ean_discount = salling_data.groupby('EAN')['Percent Discount'].nunique()
ean_with_diff_discount = ean_discount[ean_discount > 1].index

# Pivot the data
ean_discount_per_store = salling_data.pivot_table(index='EAN', columns='Store Name', values='Percent Discount')

# Filter for EANs with different discounts among stores
ean_discount_per_store_diff = ean_discount_per_store.loc[ean_with_diff_discount]


# Fill NaN values with 0
ean_discount_per_store_diff.fillna("-", inplace=True)


# Display the result
ean_discount_per_store_diff.head(10)
# Out:
# C:\Users\luicor\AppData\Local\Temp\ipykernel_46372\769900434.py:13: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# Store Name Bilka Esbjerg Bilka Herning Bilka Hillerød Bilka Holstebro  \
# EAN
# 250120                 -             -              -               -
# 250280                 -             -          49.55               -
# 250500                 -             -              -               -
# 250509                 -             -          44.56           60.11
# 250513                 -             -              -               -
# 250514                 -             -          55.76           62.09
# 250586                 -             -          40.68               -
# 250640             13.42             -          49.66               -
# 250826              53.4             -           41.4           66.73
# 250924                 -             -              -               -
#
# Store Name Bilka Horsens Bilka Ishøj Bilka Kolding Bilka Næstved Bilka Odense  \
# EAN
# 250120                 -           -             -             -            -
# 250280                 -           -             -             -            -
# 250500                 -           -             -             -            -
# 250509                 -       51.22             -             -            -
# 250513                 -           -             -             -            -
# 250514                 -       38.04             -             -            -
# 250586                 -           -             -             -            -
# 250640             36.26           -             -             -        36.95
# 250826                 -       64.07             -             -            -
# 250924                 -           -             -             -            -
#
# Store Name Bilka One Stop, Fields  ... føtex Svendborg føtex Sønderborg  \
# EAN                                ...
# 250120                          -  ...               -                -
# 250280                          -  ...               -            22.02
# 250500                          -  ...               -                -
# 250509                          -  ...           44.38                -
# 250513                          -  ...               -             62.5
# 250514                          -  ...               -                -
# 250586                      49.15  ...               -                -
# 250640                          -  ...               -                -
# 250826                          -  ...               -                -
# 250924                          -  ...               -                -
#
# Store Name føtex Vanløse føtex Vejle, Nørregade føtex Vesterbrogade Kbh  \
# EAN
# 250120                 -                      -                       -
# 250280                 -                      -                       -
# 250500                 -                      -                       -
# 250509                 -                      -                       -
# 250513                 -                      -                       -
# 250514                 -                      -                       -
# 250586                 -                      -                       -
# 250640                 -                      -                       -
# 250826                 -                      -                       -
# 250924                 -                      -                       -
#
# Store Name føtex Viborg føtex Viby føtex Windf. Hansens Center  \
# EAN
# 250120                -          -                           -
# 250280                -          -                           -
# 250500                -      43.48                           -
# 250509                -          -                           -
# 250513                -          -                           -
# 250514                -          -                           -
# 250586                -          -                           -
# 250640                -          -                           -
# 250826                -          -                           -
# 250924                -      24.24                           -
#
# Store Name føtex Ølby Centret føtex Østerbro Centret
# EAN
# 250120                      -                  22.48
# 250280                      -                      -
# 250500                      -                      -
# 250509                  55.51                      -
# 250513                   50.0                      -
# 250514                      -                      -
# 250586                      -                      -
# 250640                      -                      -
# 250826                      -                      -
# 250924                      -                      -
#
# [10 rows x 404 columns]

# %% [markdown]
# The table above indicates that each store has some autonomy in applying discounts to the same items. This suggests that the clearance model is complex, considering not only the product type but also other factors such as stock levels, duration in the store, available space, and other potential influences.

# %% [markdown]
# # Conclusion

# %% [markdown]
# This notebook showcased our utilization of the Salling Group API to map store locations and identify soon-to-expire food items for potential savings. We retrieved and visualized store data, analyzed product offerings, and processed dynamic clearance data to align surplus items with consumer needs.
#
# Key outcomes include:
#
# * A geolocation feature to identify nearby stores offering discounts.
# * Effective management of daily fluctuating data, ensuring our approach adapts to the changing nature of stock levels.
#
# For future iterations, we could integrate real-time geolocation services to enhance the user experience. Additionally, addressing the challenges in category hierarchy and depth could refine our data representation, allowing for a more nuanced analysis. This last point is unlikely to pose significant problems for our project, as we focus primarily on the lowest level of hierarchy, Category 1, with issues more prevalent in the intermediate categories.
#
# In summary, the Salling Group API provides a rich source of data that, with thoughtful processing and analysis, can be leveraged to drive initiatives in food waste reduction, consumer savings, and data-driven retail decision-making.
