# %% [markdown]
# # Similar Products

# %% [markdown]
# This notebook served as the foundation for developing the market-based analysis; however, it is not a critical component of our final project. Within this notebook, several key aspects were explored that proved to be highly valuable for our investigation.
#
# These included:
# 1. The utilization of APIs, including similar products, frequently bought together, and relevant products.
# 2. An initial attempt at market-based analysis to test and understand its potential.

# %% [markdown]
# #### New APIs
# Although the API provider offers a plethora of information, in this document we elected to investigate three APIs that were in beta phase, with the objective of achieving a comprehensive understanding of the scope of our data and its potential applications. While our primary objective was to examine the clustering of stores into food banks, we were also interested in exploring other avenues for investigation. However, apart from analyzing the popularity of relevant products, examining price discrimination, and exploring word associations between similar products, we decided not to pursue these avenues further. These areas were considered as possibilities for future work, as they require different data processing approaches that we were unable to implement due to time constraints. Moreover, they did not fully align with the specific objectives of our project.

# %% [markdown]
# ### Early Market-Based Analysis
#
# The market-based analysis presented in this document was conducted at a fundamental level, primarily to gain insight into the data structure and identify strategies for optimizing its potential. As previously stated, the data set differed significantly from that provided by other APIs, making it more challenging to align and analyze. Notwithstanding these challenges, the analysis yielded valuable insights into the relationships between relevant products and highlighted the interconnectedness of the graphs, thereby offering a more nuanced understanding of the popularity of certain items.

# %% [markdown]
# ## Imports

# %%
import requests
import pandas as pd
import requests
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
from wordcloud import WordCloud
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ## Auxiliary Functions

# %%
def get_frequently_bought_together(product):
    response = requests.get(f"https://api.sallinggroup.com/v1-beta/product-suggestions/frequently-bought-together?productId={product['prod_id']}", headers=headers)
    if response.status_code == 200:
        data = response.json()
        return [item for item in data] 
    else:
        return []

# %%
def get_frequently_bought_together_with_detail(product_id):
    response = requests.get(f"https://api.sallinggroup.com/v1-beta/product-suggestions/frequently-bought-together?productId={product_id}", headers=headers)
    if response.status_code == 200:
        data = response.json()
        return [item for item in data] 
    else:
        return []

# %%
def get_similar_products(product_id):
    response = requests.get(f"https://api.sallinggroup.com/v1-beta/product-suggestions/similar-products?productId={product_id}", headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return []

# %% [markdown]
# ## API

# %%
# key to have access to the api
headers = {
    'Authorization': 'Bearer 975e1469-316b-4f47-9cd3-f36803983908'
        #'Bearer a0b4ad91-e8d4-42ab-ae84-6cb3fd0f6024' this is not my bearer
    
}

# %%
# Relevant Products as rp
rp_url = 'https://api.sallinggroup.com/v1-beta/product-suggestions/relevant-products?query=m%C3%A6lk'


rp_response = requests.get(rp_url, headers=headers)

relevant_df = pd.DataFrame(rp_response.json()['suggestions'])

relevant_df.head()
# Out:
#             id prod_id                   title             description  \
# 0     92369031   84121      Minimælk 0,4% fedt      Minimælk 0,4% fedt
# 1     92369041   84120       Letmælk 1,5% fedt       Letmælk 1,5% fedt
# 2  93000100001   19689       Sødmælk 3,5% fedt       Sødmælk 3,5% fedt
# 3     92369051   84122   Skummetmælk 0,1% fedt   Skummetmælk 0,1% fedt
# 4  93005500001   19687  Minimælk 0,4% fedt øko  Minimælk 0,4% fedt øko
#
#                                                  img  \
# 0  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 1  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 2  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 3  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 4  https://image.prod.iposeninfra.com/bilkaimg.ph...
#
#                                link  price
# 0  https://www.bilkatogo.dk/p/84121  11.50
# 1  https://www.bilkatogo.dk/p/84120  11.75
# 2  https://www.bilkatogo.dk/p/19689  13.75
# 3  https://www.bilkatogo.dk/p/84122  10.95
# 4  https://www.bilkatogo.dk/p/19687  13.50

# %%
relevant_df.shape
# Out:
# (10, 7)

# %%
# Similar Products as sp
# This requires a porductID as a query :(
sp_url = 'https://api.sallinggroup.com/v1-beta/product-suggestions/similar-products?productId=84121'


sp_response = requests.get(sp_url, headers=headers)
print(sp_response.json())
# Convert relevant products to DataFrame
similar_df = pd.DataFrame(sp_response.json())

similar_df.head()
# Out:
# [{'id': '93001800001', 'prod_id': '19686', 'title': 'minimælk 0,4% fedt', 'description': 'Minimælk 0,4% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19686&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19686', 'price': 13.25}, {'id': '10393228', 'prod_id': '110050', 'title': 'minimælk 0,5% fedt uht', 'description': 'Minimælk 0,5% fedt UHT', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=110050&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/110050', 'price': 9.95}, {'id': '10847384', 'prod_id': '144744', 'title': 'minimælk 0,5% fedt', 'description': 'Minimælk 0,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=144744&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/144744', 'price': 11.5}, {'id': '39003801', 'prod_id': '39386', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39386&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39386', 'price': 18.5}, {'id': '10722730', 'prod_id': '145530', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=145530&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/145530', 'price': 9.95}]
#             id prod_id                   title             description  \
# 0  93001800001   19686      minimælk 0,4% fedt      Minimælk 0,4% fedt
# 1     10393228  110050  minimælk 0,5% fedt uht  Minimælk 0,5% fedt UHT
# 2     10847384  144744      minimælk 0,5% fedt      Minimælk 0,5% fedt
# 3     39003801   39386  minimælk 0,4% fedt øko  Minimælk 0,4% fedt øko
# 4     10722730  145530  minimælk 0,4% fedt øko  Minimælk 0,4% fedt øko
#
#                                                  img  \
# 0  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 1  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 2  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 3  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 4  https://image.prod.iposeninfra.com/bilkaimg.ph...
#
#                                 link  price
# 0   https://www.bilkatogo.dk/p/19686  13.25
# 1  https://www.bilkatogo.dk/p/110050   9.95
# 2  https://www.bilkatogo.dk/p/144744  11.50
# 3   https://www.bilkatogo.dk/p/39386  18.50
# 4  https://www.bilkatogo.dk/p/145530   9.95

# %%
# Frequent bought Together Products as fbt
# This requires a porductID as a query :(
fbt_url =  'https://api.sallinggroup.com/v1-beta/product-suggestions/frequently-bought-together?productId=84121'


fbt_response = requests.get(fbt_url, headers=headers)
print(fbt_response.json())
# Convert relevant products to DataFrame
fbt_df = pd.DataFrame(fbt_response.json())

fbt_df.head()
# Out:
# [{'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '89251000055', 'prod_id': '51061', 'title': 'peberfrugter røde', 'description': 'Peberfrugter røde', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=51061&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/51061', 'price': 8}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '89100500015', 'prod_id': '18323', 'title': 'gulerødder', 'description': 'Gulerødder', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18323&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18323', 'price': 11}, {'id': '89262000064', 'prod_id': '18518', 'title': 'icebergsalat', 'description': 'Icebergsalat', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18518&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18518', 'price': 11}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}]
#             id prod_id              title        description  \
# 0  89221500340   18364              agurk              Agurk
# 1  82418000110   20807    solsikkerugbrød    Solsikkerugbrød
# 2  94212000003   19721            smørbar            Smørbar
# 3  89300500105   18381            bananer            Bananer
# 4  89251000055   51061  peberfrugter røde  Peberfrugter røde
#
#                                                  img  \
# 0  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 1  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 2  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 3  https://image.prod.iposeninfra.com/bilkaimg.ph...
# 4  https://image.prod.iposeninfra.com/bilkaimg.ph...
#
#                                link  price
# 0  https://www.bilkatogo.dk/p/18364   9.00
# 1  https://www.bilkatogo.dk/p/20807  25.50
# 2  https://www.bilkatogo.dk/p/19721  25.95
# 3  https://www.bilkatogo.dk/p/18381   2.75
# 4  https://www.bilkatogo.dk/p/51061   8.00

# %% [markdown]
# ### Similar Products

# %%
relevant_df.shape
# Out:
# (10, 7)

# %%
product_graph_data = []
for pid in relevant_df['prod_id']:
    similar_products = get_similar_products(pid)
    print(pid)
    print(similar_products)
    for similar in similar_products:
        product_graph_data.append((pid, similar['prod_id']))

    

print(product_graph_data)
# Out:
# 84121
# [{'id': '93001800001', 'prod_id': '19686', 'title': 'minimælk 0,4% fedt', 'description': 'Minimælk 0,4% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19686&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19686', 'price': 13.25}, {'id': '10393228', 'prod_id': '110050', 'title': 'minimælk 0,5% fedt uht', 'description': 'Minimælk 0,5% fedt UHT', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=110050&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/110050', 'price': 9.95}, {'id': '10847384', 'prod_id': '144744', 'title': 'minimælk 0,5% fedt', 'description': 'Minimælk 0,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=144744&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/144744', 'price': 11.5}, {'id': '39003801', 'prod_id': '39386', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39386&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39386', 'price': 18.5}, {'id': '10722730', 'prod_id': '145530', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=145530&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/145530', 'price': 9.95}]
# 84120
# [{'id': '93008600001', 'prod_id': '38428', 'title': 'biodynamisk mælk 4-6% fedt øko', 'description': 'Biodynamisk mælk 4-6% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38428&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38428', 'price': 21}, {'id': '93001100001', 'prod_id': '19684', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19684&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19684', 'price': 14.25}, {'id': '93005400001', 'prod_id': '19683', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19683&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19683', 'price': 14.75}, {'id': '93005600001', 'prod_id': '19688', 'title': 'skummetmælk 0,1% fedt øko', 'description': 'Skummetmælk 0,1% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19688&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19688', 'price': 13.25}, {'id': '93002100001', 'prod_id': '19690', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19690&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19690', 'price': 14}, {'id': '39003701', 'prod_id': '39445', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39445&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39445', 'price': 18.5}, {'id': '92369051', 'prod_id': '84122', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84122&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84122', 'price': 10.95}, {'id': '72260001', 'prod_id': '81420', 'title': 'minimælk 0,4% fedt laktosefri øko', 'description': 'Minimælk 0,4% fedt laktosefri øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=81420&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/81420', 'price': 15.75}, {'id': '81470701', 'prod_id': '63088', 'title': 'ymer 3,5% fedt øko', 'description': 'Ymer 3,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=63088&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/63088', 'price': 21.95}, {'id': '10645484', 'prod_id': '128311', 'title': 'protein budding m chokoladesmag', 'description': 'Protein budding m. chokoladesmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=128311&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/128311', 'price': 14.95}]
# 19689
# [{'id': '10127759', 'prod_id': '89621', 'title': 'sødmælk 3,5% fedt', 'description': 'Sødmælk 3,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=89621&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/89621', 'price': 8.95}, {'id': '39133201', 'prod_id': '40714', 'title': 'sødmælk 3,5% fedt øko', 'description': 'Sødmælk 3,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40714&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40714', 'price': 18.95}, {'id': '93005200002', 'prod_id': '19676', 'title': 'sødmælk 3,5% fedt øko', 'description': 'Sødmælk 3,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19676&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19676', 'price': 15.25}, {'id': '93504800001', 'prod_id': '38715', 'title': 'yoghurt m jordbær og banan 2,9% fedt', 'description': 'Yoghurt m. jordbær og banan 2,9% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38715&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38715', 'price': 22.95}, {'id': '10704426', 'prod_id': '132907', 'title': 'yoghurt m vanilje og kakao', 'description': 'Yoghurt m. vanilje og kakao', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=132907&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/132907', 'price': 5}, {'id': '72675001', 'prod_id': '62535', 'title': 'yoghurt m jordbær', 'description': 'Yoghurt m. jordbær', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=62535&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/62535', 'price': 5}, {'id': '93505000001', 'prod_id': '38713', 'title': 'yoghurt m jordbær, banan og fersken 2,9% fedt', 'description': 'Yoghurt m. jordbær, banan og fersken 2,9% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38713&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38713', 'price': 16.95}, {'id': '47136001', 'prod_id': '45050', 'title': 'yoghurt m blåbær 2,7% fedt', 'description': 'Yoghurt m. blåbær 2,7% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=45050&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/45050', 'price': 20.95}, {'id': '47136101', 'prod_id': '45051', 'title': 'yoghurt m jordbær', 'description': 'Yoghurt m. jordbær', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=45051&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/45051', 'price': 18.95}, {'id': '47026601', 'prod_id': '45049', 'title': 'yoghurt m korn 2,7% fedt', 'description': 'Yoghurt m. korn 2,7% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=45049&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/45049', 'price': 20.95}]
# 84122
# [{'id': '39003701', 'prod_id': '39445', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39445&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39445', 'price': 18.5}, {'id': '93008600001', 'prod_id': '38428', 'title': 'biodynamisk mælk 4-6% fedt øko', 'description': 'Biodynamisk mælk 4-6% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38428&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38428', 'price': 21}, {'id': '10500780', 'prod_id': '117127', 'title': 'protein budding m chokoladesmag', 'description': 'Protein budding m. chokoladesmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=117127&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/117127', 'price': 15.95}, {'id': '93005600001', 'prod_id': '19688', 'title': 'skummetmælk 0,1% fedt øko', 'description': 'Skummetmælk 0,1% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19688&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19688', 'price': 13.25}, {'id': '39133101', 'prod_id': '39527', 'title': 'skummetmælk 0,1% fedt øko', 'description': 'Skummetmælk 0,1% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39527&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39527', 'price': 18.5}, {'id': '10500763', 'prod_id': '117122', 'title': 'protein budding af soja m vaniljesmag', 'description': 'Protein budding af soja m. vaniljesmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=117122&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/117122', 'price': 15.95}, {'id': '93002100001', 'prod_id': '19690', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19690&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19690', 'price': 14}, {'id': '92369041', 'prod_id': '84120', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '10866149', 'prod_id': '145573', 'title': 'baristamælk 1,5% fedt øko', 'description': 'Baristamælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=145573&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/145573', 'price': 17.95}, {'id': '10453132', 'prod_id': '120499', 'title': 'protein budding m vaniljesmag', 'description': 'Protein budding m. vaniljesmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=120499&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/120499', 'price': 12.95}]
# 19687
# [{'id': '10722730', 'prod_id': '145530', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=145530&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/145530', 'price': 9.95}, {'id': '39003801', 'prod_id': '39386', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39386&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39386', 'price': 18.5}, {'id': '93003100002', 'prod_id': '19685', 'title': 'kærnemælk 0,3% fedt', 'description': 'Kærnemælk 0,3% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19685&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19685', 'price': 13.75}]
# 19686
# [{'id': '92369031', 'prod_id': '84121', 'title': 'minimælk 0,4% fedt', 'description': 'Minimælk 0,4% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84121&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84121', 'price': 11.5}, {'id': '93003100002', 'prod_id': '19685', 'title': 'kærnemælk 0,3% fedt', 'description': 'Kærnemælk 0,3% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19685&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19685', 'price': 13.75}, {'id': '39003801', 'prod_id': '39386', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39386&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39386', 'price': 18.5}, {'id': '10722730', 'prod_id': '145530', 'title': 'minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=145530&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/145530', 'price': 9.95}]
# 19683
# [{'id': '92369041', 'prod_id': '84120', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '93005600001', 'prod_id': '19688', 'title': 'skummetmælk 0,1% fedt øko', 'description': 'Skummetmælk 0,1% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19688&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19688', 'price': 13.25}, {'id': '93001100001', 'prod_id': '19684', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19684&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19684', 'price': 14.25}, {'id': '93002100001', 'prod_id': '19690', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19690&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19690', 'price': 14}, {'id': '93200800001', 'prod_id': '19808', 'title': 'syrnet mælk naturel 0,4% fedt øko', 'description': 'Syrnet mælk naturel 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19808&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19808', 'price': 20.95}, {'id': '81470701', 'prod_id': '63088', 'title': 'ymer 3,5% fedt øko', 'description': 'Ymer 3,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=63088&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/63088', 'price': 21.95}, {'id': '93008600001', 'prod_id': '38428', 'title': 'biodynamisk mælk 4-6% fedt øko', 'description': 'Biodynamisk mælk 4-6% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38428&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38428', 'price': 21}, {'id': '96027600010', 'prod_id': '41256', 'title': 'samsø ost mellemlagret 30+', 'description': 'Samsø ost mellemlagret 30+', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=41256&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/41256', 'price': 55}, {'id': '93200300002', 'prod_id': '19795', 'title': 'syrnet mælk naturel 1,5%', 'description': 'Syrnet mælk naturel 1,5%', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19795&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19795', 'price': 20.95}, {'id': '39003701', 'prod_id': '39445', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39445&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39445', 'price': 18.5}]
# 81420
# [{'id': '93008600001', 'prod_id': '38428', 'title': 'biodynamisk mælk 4-6% fedt øko', 'description': 'Biodynamisk mælk 4-6% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38428&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38428', 'price': 21}, {'id': '10612757', 'prod_id': '128393', 'title': 'minimælk 0,5% fedt laktosefri', 'description': 'Minimælk 0,5% fedt laktosefri', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=128393&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/128393', 'price': 5.25}, {'id': '93001100001', 'prod_id': '19684', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19684&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19684', 'price': 14.25}, {'id': '10380030', 'prod_id': '110048', 'title': 'letmælk 1,5% fedt laktosefri øko', 'description': 'Letmælk 1,5% fedt laktosefri øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=110048&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/110048', 'price': 18.5}, {'id': '73306901', 'prod_id': '61488', 'title': 'chokoladebudding', 'description': 'Chokoladebudding', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61488&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61488', 'price': 5.95}, {'id': '10379659', 'prod_id': '110049', 'title': 'sødmælk 3,5% fedt laktosefri øko', 'description': 'Sødmælk 3,5% fedt laktosefri øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=110049&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/110049', 'price': 19.5}, {'id': '93002100001', 'prod_id': '19690', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19690&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19690', 'price': 14}, {'id': '92369041', 'prod_id': '84120', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '93061400001', 'prod_id': '19525', 'title': 'drikkeyoghurt m blåbær laktosefri', 'description': 'Drikkeyoghurt m. blåbær laktosefri', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19525&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19525', 'price': 12}, {'id': '10218127', 'prod_id': '105434', 'title': 'danbo i skiver lagret 45+', 'description': 'Danbo i skiver lagret 45+', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=105434&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/105434', 'price': 32.95}]
# 19684
# [{'id': '93002100001', 'prod_id': '19690', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19690&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19690', 'price': 14}, {'id': '92369041', 'prod_id': '84120', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '93005600001', 'prod_id': '19688', 'title': 'skummetmælk 0,1% fedt øko', 'description': 'Skummetmælk 0,1% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19688&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19688', 'price': 13.25}, {'id': '93005400001', 'prod_id': '19683', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19683&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19683', 'price': 14.75}, {'id': '81470701', 'prod_id': '63088', 'title': 'ymer 3,5% fedt øko', 'description': 'Ymer 3,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=63088&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/63088', 'price': 21.95}, {'id': '93008600001', 'prod_id': '38428', 'title': 'biodynamisk mælk 4-6% fedt øko', 'description': 'Biodynamisk mælk 4-6% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38428&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38428', 'price': 21}, {'id': '72260001', 'prod_id': '81420', 'title': 'minimælk 0,4% fedt laktosefri øko', 'description': 'Minimælk 0,4% fedt laktosefri øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=81420&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/81420', 'price': 15.75}, {'id': '94503800010', 'prod_id': '50179', 'title': 'fedtegrever', 'description': 'Fedtegrever', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=50179&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/50179', 'price': 16.5}, {'id': '93200800001', 'prod_id': '19808', 'title': 'syrnet mælk naturel 0,4% fedt øko', 'description': 'Syrnet mælk naturel 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19808&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19808', 'price': 20.95}, {'id': '10645483', 'prod_id': '128259', 'title': 'protein budding m karamelsmag', 'description': 'Protein budding m. karamelsmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=128259&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/128259', 'price': 14.95}]
# 19688
# [{'id': '93002100001', 'prod_id': '19690', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19690&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19690', 'price': 14}, {'id': '93005400001', 'prod_id': '19683', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19683&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19683', 'price': 14.75}, {'id': '93001100001', 'prod_id': '19684', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19684&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19684', 'price': 14.25}, {'id': '92369041', 'prod_id': '84120', 'title': 'letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '93008600001', 'prod_id': '38428', 'title': 'biodynamisk mælk 4-6% fedt øko', 'description': 'Biodynamisk mælk 4-6% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=38428&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/38428', 'price': 21}, {'id': '92369051', 'prod_id': '84122', 'title': 'skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84122&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84122', 'price': 10.95}, {'id': '39003701', 'prod_id': '39445', 'title': 'letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39445&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39445', 'price': 18.5}, {'id': '10645484', 'prod_id': '128311', 'title': 'protein budding m chokoladesmag', 'description': 'Protein budding m. chokoladesmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=128311&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/128311', 'price': 14.95}, {'id': '10645483', 'prod_id': '128259', 'title': 'protein budding m karamelsmag', 'description': 'Protein budding m. karamelsmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=128259&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/128259', 'price': 14.95}, {'id': '10453131', 'prod_id': '113661', 'title': 'protein budding m chokoladesmag', 'description': 'Protein budding m. chokoladesmag', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=113661&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/113661', 'price': 12.95}]
# [('84121', '19686'), ('84121', '110050'), ('84121', '144744'), ('84121', '39386'), ('84121', '145530'), ('84120', '38428'), ('84120', '19684'), ('84120', '19683'), ('84120', '19688'), ('84120', '19690'), ('84120', '39445'), ('84120', '84122'), ('84120', '81420'), ('84120', '63088'), ('84120', '128311'), ('19689', '89621'), ('19689', '40714'), ('19689', '19676'), ('19689', '38715'), ('19689', '132907'), ('19689', '62535'), ('19689', '38713'), ('19689', '45050'), ('19689', '45051'), ('19689', '45049'), ('84122', '39445'), ('84122', '38428'), ('84122', '117127'), ('84122', '19688'), ('84122', '39527'), ('84122', '117122'), ('84122', '19690'), ('84122', '84120'), ('84122', '145573'), ('84122', '120499'), ('19687', '145530'), ('19687', '39386'), ('19687', '19685'), ('19686', '84121'), ('19686', '19685'), ('19686', '39386'), ('19686', '145530'), ('19683', '84120'), ('19683', '19688'), ('19683', '19684'), ('19683', '19690'), ('19683', '19808'), ('19683', '63088'), ('19683', '38428'), ('19683', '41256'), ('19683', '19795'), ('19683', '39445'), ('81420', '38428'), ('81420', '128393'), ('81420', '19684'), ('81420', '110048'), ('81420', '61488'), ('81420', '110049'), ('81420', '19690'), ('81420', '84120'), ('81420', '19525'), ('81420', '105434'), ('19684', '19690'), ('19684', '84120'), ('19684', '19688'), ('19684', '19683'), ('19684', '63088'), ('19684', '38428'), ('19684', '81420'), ('19684', '50179'), ('19684', '19808'), ('19684', '128259'), ('19688', '19690'), ('19688', '19683'), ('19688', '19684'), ('19688', '84120'), ('19688', '38428'), ('19688', '84122'), ('19688', '39445'), ('19688', '128311'), ('19688', '128259'), ('19688', '113661')]

# %%
G = nx.Graph()
G.add_edges_from(product_graph_data)

degree_dict = dict(G.degree())

node_sizes = [500 + 50 * degree_dict[node] for node in G.nodes()]  
node_colors = [degree_dict[node] for node in G.nodes()] 


pos = nx.spring_layout(G, k=0.9, iterations=100)


fig, ax = plt.subplots(figsize=(15, 10))

nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors, cmap=plt.cm.coolwarm, alpha=0.9, ax=ax)
nx.draw_networkx_edges(G, pos, edge_color='gray', width=2, ax=ax)
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif', ax=ax)

sm = mpl.cm.ScalarMappable(cmap=plt.cm.coolwarm, norm=plt.Normalize(vmin=min(node_colors), vmax=max(node_colors)))
sm.set_array([]) 
plt.colorbar(sm, ax=ax, label="Node Degree (Connections)")

ax.set_title('Product Similarity Graph with Node Size and Color by Connections')
plt.show()

# %%
# Get the largest connected component
largest_cc = max(nx.connected_components(G), key=len)
print("Nodes in the largest connected component:", len(largest_cc))
# Out:
# Nodes in the largest connected component: 28

# %%
# Calculate the degree of each node (number of connections)
degree_centrality = nx.degree_centrality(G)
print("Most central node (highest degree):", max(degree_centrality, key=degree_centrality.get))
# Out:
# Most central node (highest degree): 84120

# %% [markdown]
# ### Relevant Products

# %%
relevant_df.size
# Out:
# 70

# %%
plt.figure(figsize=(10, 6))
relevant_df['price'].hist(bins=5)
plt.title("Price Distribution of Products")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
text = " ".join(relevant_df["description"])

wordcloud = WordCloud(width=800, height=400, background_color="white", colormap="viridis", max_words=50).generate(text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Most Relevant Products")
plt.show()

# %%
organic_df = relevant_df[relevant_df['title'].str.contains("øko", case=False)]

organic_percentage = (len(organic_df) / len(relevant_df)) * 100
print(f"Percentage of organic products: {organic_percentage:.2f}%")

non_organic_df = relevant_df[~relevant_df['title'].str.contains("øko", case=False)]
print("Average price of organic products:", organic_df['price'].mean())
print("Average price of non-organic products:", non_organic_df['price'].mean())
# Out:
# Percentage of organic products: 40.00%
# Average price of organic products: 14.3125
# Average price of non-organic products: 12.575000000000001

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(relevant_df['price'], vert=False)
plt.title("Box Plot of Product Prices")
plt.xlabel("Price")
plt.show()

# %% [markdown]
# ### Market Based Model

# %%
relevant_df["prod_id"]
# Out:
# 0    84121
# 1    84120
# 2    19689
# 3    84122
# 4    19687
# 5    19686
# 6    19683
# 7    81420
# 8    19684
# 9    19688
# Name: prod_id, dtype: object

# %%
transactions = []
rows_as_dicts = relevant_df.to_dict(orient='records')

for row in rows_as_dicts:
    transaction = []
    #print(row)
    fbt_items = get_frequently_bought_together(row)
    #print(fbt_items)
    transaction.append(row)
    transaction = transaction + fbt_items
    print(transaction)
    transactions.append(transaction)

print("Transactions:\n")
print(transactions)
# Out:
# [{'id': '92369031', 'prod_id': '84121', 'title': 'Minimælk 0,4% fedt', 'description': 'Minimælk 0,4% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84121&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84121', 'price': 11.5}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '89251000055', 'prod_id': '51061', 'title': 'peberfrugter røde', 'description': 'Peberfrugter røde', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=51061&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/51061', 'price': 8}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '89100500015', 'prod_id': '18323', 'title': 'gulerødder', 'description': 'Gulerødder', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18323&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18323', 'price': 11}, {'id': '89262000064', 'prod_id': '18518', 'title': 'icebergsalat', 'description': 'Icebergsalat', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18518&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18518', 'price': 11}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}]
# [{'id': '92369041', 'prod_id': '84120', 'title': 'Letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '89100500015', 'prod_id': '18323', 'title': 'gulerødder', 'description': 'Gulerødder', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18323&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18323', 'price': 11}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '89251000055', 'prod_id': '51061', 'title': 'peberfrugter røde', 'description': 'Peberfrugter røde', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=51061&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/51061', 'price': 8}, {'id': '90707431', 'prod_id': '85465', 'title': 'finvalsede havregryn', 'description': 'Finvalsede havregryn', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=85465&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/85465', 'price': 9.95}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '32566601', 'prod_id': '40258', 'title': 'frilandsæg s/m/l', 'description': 'Frilandsæg S/M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40258&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40258', 'price': 33.95}]
# [{'id': '93000100001', 'prod_id': '19689', 'title': 'Sødmælk 3,5% fedt', 'description': 'Sødmælk 3,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19689&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19689', 'price': 13.75}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '10698631', 'prod_id': '132863', 'title': 'piskefløde 36% fedt', 'description': 'Piskefløde 36% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=132863&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/132863', 'price': 26.95}, {'id': '92105731', 'prod_id': '84106', 'title': 'creme fraiche 18% fedt', 'description': 'Creme fraiche 18% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84106&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84106', 'price': 19.5}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '32566601', 'prod_id': '40258', 'title': 'frilandsæg s/m/l', 'description': 'Frilandsæg S/M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40258&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40258', 'price': 33.95}]
# [{'id': '92369051', 'prod_id': '84122', 'title': 'Skummetmælk 0,1% fedt', 'description': 'Skummetmælk 0,1% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84122&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84122', 'price': 10.95}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '89262000064', 'prod_id': '18518', 'title': 'icebergsalat', 'description': 'Icebergsalat', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18518&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18518', 'price': 11}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '90707431', 'prod_id': '85465', 'title': 'finvalsede havregryn', 'description': 'Finvalsede havregryn', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=85465&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/85465', 'price': 9.95}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89254000078', 'prod_id': '41688', 'title': 'rød snackpeber', 'description': 'Rød snackpeber', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=41688&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/41688', 'price': 20}, {'id': '89151000016', 'prod_id': '18330', 'title': 'broccoli', 'description': 'Broccoli', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18330&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18330', 'price': 10}, {'id': '89100500015', 'prod_id': '18323', 'title': 'gulerødder', 'description': 'Gulerødder', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18323&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18323', 'price': 11}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}]
# [{'id': '93005500001', 'prod_id': '19687', 'title': 'Minimælk 0,4% fedt øko', 'description': 'Minimælk 0,4% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19687&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19687', 'price': 13.5}, {'id': '32861601', 'prod_id': '39411', 'title': 'finvalsede havregryn øko', 'description': 'Finvalsede havregryn øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39411&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39411', 'price': 11.95}, {'id': '89500800012', 'prod_id': '37982', 'title': 'gulerødder øko', 'description': 'Gulerødder øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=37982&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/37982', 'price': 14}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '51892901', 'prod_id': '53366', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53366&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53366', 'price': 35}, {'id': '10340165', 'prod_id': '108507', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=108507&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/108507', 'price': 28.5}, {'id': '89300505023', 'prod_id': '72008', 'title': 'bananer 4 pak øko', 'description': 'Bananer 4 pak øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=72008&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/72008', 'price': 10}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '32566601', 'prod_id': '40258', 'title': 'frilandsæg s/m/l', 'description': 'Frilandsæg S/M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40258&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40258', 'price': 33.95}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}]
# [{'id': '93001800001', 'prod_id': '19686', 'title': 'Minimælk 0,4% fedt', 'description': 'Minimælk 0,4% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19686&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19686', 'price': 13.25}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '37918301', 'prod_id': '41685', 'title': 'mozzarella 19% fedt', 'description': 'Mozzarella 19% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=41685&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/41685', 'price': 9.25}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '89262000064', 'prod_id': '18518', 'title': 'icebergsalat', 'description': 'Icebergsalat', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18518&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18518', 'price': 11}, {'id': '89251000055', 'prod_id': '51061', 'title': 'peberfrugter røde', 'description': 'Peberfrugter røde', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=51061&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/51061', 'price': 8}, {'id': '32566601', 'prod_id': '40258', 'title': 'frilandsæg s/m/l', 'description': 'Frilandsæg S/M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40258&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40258', 'price': 33.95}]
# [{'id': '93005400001', 'prod_id': '19683', 'title': 'Letmælk 1,5% fedt øko', 'description': 'Letmælk 1,5% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19683&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19683', 'price': 14.75}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}, {'id': '89500800012', 'prod_id': '37982', 'title': 'gulerødder øko', 'description': 'Gulerødder øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=37982&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/37982', 'price': 14}, {'id': '32861601', 'prod_id': '39411', 'title': 'finvalsede havregryn øko', 'description': 'Finvalsede havregryn øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39411&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39411', 'price': 11.95}, {'id': '89251005006', 'prod_id': '41388', 'title': 'california peberfrugter øko', 'description': 'California peberfrugter øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=41388&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/41388', 'price': 20}, {'id': '10340165', 'prod_id': '108507', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=108507&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/108507', 'price': 28.5}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '51892901', 'prod_id': '53366', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53366&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53366', 'price': 35}, {'id': '89300505023', 'prod_id': '72008', 'title': 'bananer 4 pak øko', 'description': 'Bananer 4 pak øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=72008&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/72008', 'price': 10}, {'id': '10218680', 'prod_id': '119482', 'title': 'hakkede tomater øko', 'description': 'Hakkede tomater øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=119482&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/119482', 'price': 6.5}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}]
# [{'id': '72260001', 'prod_id': '81420', 'title': 'Minimælk 0,4% fedt laktosefri øko', 'description': 'Minimælk 0,4% fedt laktosefri øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=81420&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/81420', 'price': 15.75}, {'id': '93141500010', 'prod_id': '19607', 'title': 'fraiche af syrnet fløde 13% fedt laktosefri', 'description': 'Fraiche af syrnet fløde 13% fedt laktosefri', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19607&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19607', 'price': 11.95}, {'id': '93156000001', 'prod_id': '19594', 'title': 'piskefløde 36% fedt laktosefri', 'description': 'Piskefløde 36% fedt laktosefri', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19594&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19594', 'price': 15.5}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}, {'id': '32566601', 'prod_id': '40258', 'title': 'frilandsæg s/m/l', 'description': 'Frilandsæg S/M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40258&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40258', 'price': 33.95}, {'id': '89300505023', 'prod_id': '72008', 'title': 'bananer 4 pak øko', 'description': 'Bananer 4 pak øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=72008&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/72008', 'price': 10}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '10395848', 'prod_id': '135634', 'title': 'cherryblomme tomater', 'description': 'Cherryblomme tomater', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=135634&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/135634', 'price': 20}, {'id': '89151000016', 'prod_id': '18330', 'title': 'broccoli', 'description': 'Broccoli', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18330&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18330', 'price': 10}, {'id': '51892901', 'prod_id': '53366', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53366&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53366', 'price': 35}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}]
# [{'id': '93001100001', 'prod_id': '19684', 'title': 'Letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19684&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19684', 'price': 14.25}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}, {'id': '10693495', 'prod_id': '132803', 'title': 'piskefløde 36% fedt', 'description': 'Piskefløde 36% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=132803&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/132803', 'price': 31.5}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '13958201', 'prod_id': '18379', 'title': 'æbler', 'description': 'Æbler', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18379&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18379', 'price': 2.75}, {'id': '90707691', 'prod_id': '83545', 'title': 'vådservietter', 'description': 'Vådservietter', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=83545&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/83545', 'price': 11.95}, {'id': '32566601', 'prod_id': '40258', 'title': 'frilandsæg s/m/l', 'description': 'Frilandsæg S/M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40258&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40258', 'price': 33.95}]
# [{'id': '93005600001', 'prod_id': '19688', 'title': 'Skummetmælk 0,1% fedt øko', 'description': 'Skummetmælk 0,1% fedt øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19688&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19688', 'price': 13.25}, {'id': '51892901', 'prod_id': '53366', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53366&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53366', 'price': 35}, {'id': '89500800012', 'prod_id': '37982', 'title': 'gulerødder øko', 'description': 'Gulerødder øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=37982&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/37982', 'price': 14}, {'id': '32861601', 'prod_id': '39411', 'title': 'finvalsede havregryn øko', 'description': 'Finvalsede havregryn øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39411&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39411', 'price': 11.95}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}, {'id': '10340165', 'prod_id': '108507', 'title': 'æg m/l øko', 'description': 'Æg M/L øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=108507&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/108507', 'price': 28.5}, {'id': '33111501', 'prod_id': '39100', 'title': 'æblejuice fra koncentrat øko', 'description': 'Æblejuice fra koncentrat øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=39100&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/39100', 'price': 9.5}, {'id': '89300505023', 'prod_id': '72008', 'title': 'bananer 4 pak øko', 'description': 'Bananer 4 pak øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=72008&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/72008', 'price': 10}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}]
# Transactions:
#
# [[{'id': '92369031', 'prod_id': '84121', 'title': 'Minimælk 0,4% fedt', 'description': 'Minimælk 0,4% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84121&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84121', 'price': 11.5}, {'id': '89221500340', 'prod_id': '18364', 'title': 'agurk', 'description': 'Agurk', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18364&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18364', 'price': 9}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '89251000055', 'prod_id': '51061', 'title': 'peberfrugter røde', 'description': 'Peberfrugter røde', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=51061&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/51061', 'price': 8}, {'id': '89331000460', 'prod_id': '40446', 'title': 'stenfrie røde druer', 'description': 'Stenfrie røde druer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=40446&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/40446', 'price': 24}, {'id': '89100500015', 'prod_id': '18323', 'title': 'gulerødder', 'description': 'Gulerødder', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18323&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18323', 'price': 11}, {'id': '89262000064', 'prod_id': '18518', 'title': 'icebergsalat', 'description': 'Icebergsalat', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18518&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18518', 'price': 11}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '32889301', 'prod_id': '61090', 'title': 'agurk øko', 'description': 'Agurk øko', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=61090&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/61090', 'price': 10}], [{'id': '92369041', 'prod_id': '84120', 'title': 'Letmælk 1,5% fedt', 'description': 'Letmælk 1,5% fedt', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=84120&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/84120', 'price': 11.75}, {'id': '82418000110', 'prod_id': '20807', 'title': 'solsikkerugbrød', 'description': 'Solsikkerugbrød', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=20807&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/20807', 'price': 25.5}, {'id': '94212000003', 'prod_id': '19721', 'title': 'smørbar', 'description': 'Smørbar', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=19721&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/19721', 'price': 25.95}, {'id': '89300500105', 'prod_id': '18381', 'title': 'bananer', 'description': 'Bananer', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18381&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/18381', 'price': 2.75}, {'id': '51926001', 'prod_id': '53365', 'title': 'skrabeæg m/l', 'description': 'Skrabeæg M/L', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=53365&imgType=jpeg', 'link': 'https://www.bilkatogo.dk/p/53365', 'price': 27.25}, {'id': '89100500015', 'prod_id': '18323', 'title': 'gulerødder', 'description': 'Gulerødder', 'img': 'https://image.prod.iposeninfra.com/bilkaimg.php?pid=18323&imgType=jpeg', 'link': 'https://www.bilkat ...

# %%
transactions_ids = []
for transaction in transactions:
    trans = []
    for product in transaction:
        trans.append(product['prod_id'])
    transactions_ids.append(trans)

print(transactions_ids)
# Out:
# [['84121', '18364', '20807', '19721', '18381', '51061', '40446', '18323', '18518', '53365', '61090'], ['84120', '20807', '19721', '18381', '53365', '18323', '18364', '51061', '85465', '40446', '40258'], ['19689', '53365', '40446', '19721', '18381', '132863', '84106', '61090', '18364', '20807', '40258'], ['84122', '53365', '18364', '18518', '40446', '85465', '19721', '41688', '18330', '18323', '61090'], ['19687', '39411', '37982', '61090', '19721', '53366', '108507', '72008', '20807', '40258', '40446'], ['19686', '18381', '19721', '53365', '18364', '40446', '41685', '20807', '18518', '51061', '40258'], ['19683', '61090', '37982', '39411', '41388', '108507', '19721', '53366', '72008', '119482', '40446'], ['81420', '19607', '19594', '61090', '40258', '72008', '19721', '135634', '18330', '53366', '20807'], ['19684', '19721', '18381', '53365', '61090', '132803', '18364', '20807', '18379', '83545', '40258'], ['19688', '53366', '37982', '39411', '19721', '40446', '61090', '108507', '39100', '72008', '20807']]

# %%
transactions_df = pd.DataFrame(transactions_ids)
max_columns = transactions_df.shape[1]
transactions_df.columns = [f'Product {i+1}' for i in range(max_columns)]

transactions_df = transactions_df.fillna(0)
print(transactions_df.shape)
print(relevant_df.shape)
print(transactions_df.head())
# Out:
# (10, 11)
# (10, 7)
#   Product 1 Product 2 Product 3 Product 4 Product 5 Product 6 Product 7  \
# 0     84121     18364     20807     19721     18381     51061     40446
# 1     84120     20807     19721     18381     53365     18323     18364
# 2     19689     53365     40446     19721     18381    132863     84106
# 3     84122     53365     18364     18518     40446     85465     19721
# 4     19687     39411     37982     61090     19721     53366    108507
#
#   Product 8 Product 9 Product 10 Product 11
# 0     18323     18518      53365      61090
# 1     51061     85465      40446      40258
# 2     61090     18364      20807      40258
# 3     41688     18330      18323      61090
# 4     72008     20807      40258      40446

# %%
te = TransactionEncoder()
te_array = te.fit(transactions_ids).transform(transactions_ids)
transaction_matrix = pd.DataFrame(te_array, columns=te.columns_)
print(transaction_matrix.head())
# Out:
#    108507  119482  132803  132863  135634  18323  18330  18364  18379  18381  \
# 0   False   False   False   False   False   True  False   True  False   True
# 1   False   False   False   False   False   True  False   True  False   True
# 2   False   False   False    True   False  False  False   True  False   True
# 3   False   False   False   False   False   True   True   True  False  False
# 4    True   False   False   False   False  False  False  False  False  False
#
#    ...  53366  61090  72008  81420  83545  84106  84120  84121  84122  85465
# 0  ...  False   True  False  False  False  False  False   True  False  False
# 1  ...  False  False  False  False  False  False   True  False  False   True
# 2  ...  False   True  False  False  False   True  False  False  False  False
# 3  ...  False   True  False  False  False  False  False  False   True   True
# 4  ...   True   True   True  False  False  False  False  False  False  False
#
# [5 rows x 41 columns]

# %%
frequent_itemsets = apriori(transaction_matrix, min_support=0.5, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
print(frequent_itemsets[frequent_itemsets['itemsets'].apply(len) >= 2])
# Out:
#     support                             itemsets
# 8       0.5                       (18381, 18364)
# 9       0.6                       (19721, 18364)
# 10      0.5                       (18364, 20807)
# 11      0.5                       (40446, 18364)
# 12      0.6                       (53365, 18364)
# 13      0.5                       (18381, 19721)
# 14      0.5                       (18381, 20807)
# 15      0.5                       (18381, 53365)
# 16      0.8                       (19721, 20807)
# 17      0.6                       (19721, 40258)
# 18      0.8                       (19721, 40446)
# 19      0.6                       (19721, 53365)
# 20      0.8                       (19721, 61090)
# 21      0.6                       (40258, 20807)
# 22      0.6                       (40446, 20807)
# 23      0.5                       (53365, 20807)
# 24      0.6                       (61090, 20807)
# 25      0.5                       (53365, 40446)
# 26      0.6                       (40446, 61090)
# 27      0.5                (18381, 19721, 18364)
# 28      0.5                (18381, 18364, 20807)
# 29      0.5                (18381, 53365, 18364)
# 30      0.5                (19721, 18364, 20807)
# 31      0.5                (19721, 40446, 18364)
# 32      0.6                (19721, 53365, 18364)
# 33      0.5                (53365, 18364, 20807)
# 34      0.5                (53365, 40446, 18364)
# 35      0.5                (18381, 19721, 20807)
# 36      0.5                (18381, 19721, 53365)
# 37      0.5                (18381, 53365, 20807)
# 38      0.6                (19721, 40258, 20807)
# 39      0.6                (19721, 40446, 20807)
# 40      0.5                (19721, 53365, 20807)
# 41      0.6                (19721, 61090, 20807)
# 42      0.5                (19721, 53365, 40446)
# 43      0.6                (19721, 40446, 61090)
# 44      0.5         (18381, 19721, 18364, 20807)
# 45      0.5         (18381, 19721, 53365, 18364)
# 46      0.5         (18381, 53365, 18364, 20807)
# 47      0.5         (19721, 53365, 18364, 20807)
# 48      0.5         (19721, 53365, 40446, 18364)
# 49      0.5         (18381, 19721, 53365, 20807)
# 50      0.5  (53365, 18364, 18381, 19721, 20807)

# %%
print(frequent_itemsets[frequent_itemsets['itemsets'].apply(len) < 2])
# Out:
#    support itemsets
# 0      0.6  (18364)
# 1      0.5  (18381)
# 2      1.0  (19721)
# 3      0.8  (20807)
# 4      0.6  (40258)
# 5      0.8  (40446)
# 6      0.6  (53365)
# 7      0.8  (61090)

# %%
lookup = {}
for transaction in transactions:
    for product in transaction:
        if isinstance(product, dict): 
            lookup[product['prod_id']] = product

for _, row in frequent_itemsets[frequent_itemsets['itemsets'].apply(len) >= 2].iterrows():
    support = row['support']
    itemset = row['itemsets']
    
    item_details = [lookup.get(prod_id, {'title': 'Unknown', 'prod_id': prod_id, 'description': 'Unknown'}) for prod_id in itemset]
    
    print(f"Itemset with support {support}:")
    for item in item_details:
        print(f"- Product ID: {item['prod_id']}, Title: {item.get('title', 'Unknown')}, Description: {item.get('description', 'Unknown')}")
    print("-" * 40)
# Out:
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# ----------------------------------------
# Itemset with support 0.8:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 40258, Title: frilandsæg s/m/l, Description: Frilandsæg S/M/L
# ----------------------------------------
# Itemset with support 0.8:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# ----------------------------------------
# Itemset with support 0.8:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 61090, Title: agurk øko, Description: Agurk øko
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 40258, Title: frilandsæg s/m/l, Description: Frilandsæg S/M/L
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 61090, Title: agurk øko, Description: Agurk øko
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 61090, Title: agurk øko, Description: Agurk øko
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 40258, Title: frilandsæg s/m/l, Description: Frilandsæg S/M/L
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 61090, Title: agurk øko, Description: Agurk øko
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 61090, Title: agurk øko, Description: Agurk øko
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# - Product ID: 18364, Title: agurk, Description: Agurk
# - Product ID: 18381, Title: bananer, Description: Bananer
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------

# %%
lookup = {}
for transaction in transactions:
    for product in transaction:
        if isinstance(product, dict): 
            lookup[product['prod_id']] = product

for _, row in frequent_itemsets[frequent_itemsets['itemsets'].apply(len) < 2].iterrows():
    support = row['support']
    itemset = row['itemsets']
    
    item_details = [lookup.get(prod_id, {'title': 'Unknown', 'prod_id': prod_id, 'description': 'Unknown'}) for prod_id in itemset]
    
    print(f"Itemset with support {support}:")
    for item in item_details:
        print(f"- Product ID: {item['prod_id']}, Title: {item.get('title', 'Unknown')}, Description: {item.get('description', 'Unknown')}")
    print("-" * 40)
# Out:
# Itemset with support 0.6:
# - Product ID: 18364, Title: agurk, Description: Agurk
# ----------------------------------------
# Itemset with support 0.5:
# - Product ID: 18381, Title: bananer, Description: Bananer
# ----------------------------------------
# Itemset with support 1.0:
# - Product ID: 19721, Title: smørbar, Description: Smørbar
# ----------------------------------------
# Itemset with support 0.8:
# - Product ID: 20807, Title: solsikkerugbrød, Description: Solsikkerugbrød
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 40258, Title: frilandsæg s/m/l, Description: Frilandsæg S/M/L
# ----------------------------------------
# Itemset with support 0.8:
# - Product ID: 40446, Title: stenfrie røde druer, Description: Stenfrie røde druer
# ----------------------------------------
# Itemset with support 0.6:
# - Product ID: 53365, Title: skrabeæg m/l, Description: Skrabeæg M/L
# ----------------------------------------
# Itemset with support 0.8:
# - Product ID: 61090, Title: agurk øko, Description: Agurk øko
# ----------------------------------------

# %%
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#     antecedents                   consequents  support  confidence      lift
# 0       (18381)                       (18364)      0.5    1.000000  1.666667
# 1       (18364)                       (18381)      0.5    0.833333  1.666667
# 2       (19721)                       (18364)      0.6    0.600000  1.000000
# 3       (18364)                       (19721)      0.6    1.000000  1.000000
# 4       (18364)                       (20807)      0.5    0.833333  1.041667
# ..          ...                           ...      ...         ...       ...
# 249     (53365)  (18381, 20807, 19721, 18364)      0.5    0.833333  1.666667
# 250     (18364)  (18381, 19721, 53365, 20807)      0.5    0.833333  1.666667
# 251     (18381)  (20807, 19721, 53365, 18364)      0.5    1.000000  2.000000
# 252     (19721)  (18381, 20807, 53365, 18364)      0.5    0.500000  1.000000
# 253     (20807)  (18381, 19721, 53365, 18364)      0.5    0.625000  1.250000
#
# [254 rows x 5 columns]

# %%
G = nx.DiGraph()

for _, rule in rules.iterrows():
    for antecedent in rule['antecedents']:
        for consequent in rule['consequents']:
            G.add_edge(antecedent, consequent, weight=rule['support'])

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.5)
nx.draw(G, pos, with_labels=True, node_size=5000, node_color="lightblue", font_size=10, font_weight="bold")
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title("Association Rules Network")
plt.show()

# %% [markdown]
# - Lift measures how much more likely it is that the consequent will occur given the antecedent, compared to its independent occurrence. It quantifies the strength of the association between antecedents and consequents.
#     - Lift > 1: Positive association. The antecedent increases the likelihood of the consequent.
#     - Lift = 1: No association. The antecedent and consequent are independent.
#     - Lift < 1: Negative association. The antecedent reduces the likelihood of the consequent.
# - Confidence measures the probability that the consequent is purchased given that the antecedent is purchased
# - Support measures how frequently the itemset occurs in the dataset

# %% [markdown]
# ### Conclusion
#
# Although we ultimately did not pursue these topics further, it is important to note the significant potential for further investigation and integration with our food banks. The simpler market-based analysis facilitated the creation of a more straightforward bundle solution, executed with the Apriori algorithm on **4_Apriori_Bundle_Analysis.ipynb**. The graph analysis demonstrated not only the interconnectivity of the products but also provided valuable insights into the structural organization of the APIs and the potential for integrating them. Additionally, it revealed the popularity of various items, which was an intriguing outcome.
#
# While these approaches were found to be promising, they were ultimately set aside in favor of pursuing alternative avenues of investigation.
