# %%
import pandas as pd

#import salling data that is a pickle file 
df = pd.read_pickle('data/salling_data.pkl')

#import recipe data
df2 = pd.read_csv('data/recipes_data.csv')

# %%
#keep the only columns we need
df = df[['Store Name', 'Category 1','Cleaned Ingredients', 'Original Price', 'New Price', 'Discount','Percent Discount']]
df.head()

#print(df['Cleaned Ingredients'].unique())
# Out:
#      Store Name         Category 1 Cleaned Ingredients  Original Price  \
# 1  Netto Lyngby        Hotdog Buns          hotdog bun           14.00
# 2  Netto Lyngby    Light Dark Buns      light dark bun           25.00
# 3  Netto Lyngby  Seeded Rye Breads           rye bread            7.75
# 4  Netto Lyngby         Buttermilk          buttermilk           13.25
# 5  Netto Lyngby         Other Pork                pork           59.95
#
#    New Price  Discount  Percent Discount
# 1        7.0      7.00             50.00
# 2       15.0     10.00             40.00
# 3        6.0      1.75             22.58
# 4       10.0      3.25             24.53
# 5       36.0     23.95             39.95

# %%
df2.head(5)
# Out:
#    id source                                               link title  \
# 0   1    bbc  https://www.bbc.co.uk/food/recipes/healthy_chi...
# 1   1    bbc  https://www.bbc.co.uk/food/recipes/healthy_chi...
# 2   1    bbc  https://www.bbc.co.uk/food/recipes/healthy_chi...
# 3   1    bbc  https://www.bbc.co.uk/food/recipes/healthy_chi...
# 4   1    bbc  https://www.bbc.co.uk/food/recipes/healthy_chi...
#
#             0
# 0  beef mince
# 1   red onion
# 2      garlic
# 3   courgette
# 4   aubergine

# %%
#how many recipes we have, count unique titles
print(f"there are {df2['id'].nunique()} unique recipes")

#how many products we have, count unique description_en
print(f"there are {df2['description_en'].nunique()} unique ingredients")
# Out:
# there are 1550 unique recipes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\luicor\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'description_en'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 5
#       2 print(f"there are {df2['id'].nunique()} unique recipes")
#       4 #how many products we have, count unique description_en
# ----> 5 print(f"there are {df2['description_en'].nunique()} unique ingredients")
#
# File c:\Users\luicor\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Users\luicor\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'description_en'

# %%
# Merge the dataframes on the 'Category 1' column from df and 'description_en' column from df2
merged_df = pd.merge(df2, df, left_on='description_en', right_on='Cleaned Ingredients', how='left')

# Display the merged dataframe
merged_df.head(5)
# Out:
#   id                                               link  \
# 0  1  https://www.bbc.co.uk/food/recipes/slow_cooker...
# 1  1  https://www.bbc.co.uk/food/recipes/slow_cooker...
# 2  1  https://www.bbc.co.uk/food/recipes/slow_cooker...
# 3  1  https://www.bbc.co.uk/food/recipes/slow_cooker...
# 4  1  https://www.bbc.co.uk/food/recipes/slow_cooker...
#
#                           title                      title_en description_en  \
# 0  Slow cooker pea and ham soup  Slow cooker pea and ham soup  sunflower oil
# 1  Slow cooker pea and ham soup  Slow cooker pea and ham soup          onion
# 2  Slow cooker pea and ham soup  Slow cooker pea and ham soup         celery
# 3  Slow cooker pea and ham soup  Slow cooker pea and ham soup        carrots
# 4  Slow cooker pea and ham soup  Slow cooker pea and ham soup     split peas
#
#   source Store Name Category 1 Cleaned Ingredients  Original Price  New Price  \
# 0    bbc        NaN        NaN                 NaN             NaN        NaN
# 1    bbc        NaN        NaN                 NaN             NaN        NaN
# 2    bbc        NaN        NaN                 NaN             NaN        NaN
# 3    bbc        NaN        NaN                 NaN             NaN        NaN
# 4    bbc        NaN        NaN                 NaN             NaN        NaN
#
#    Discount  Percent Discount
# 0       NaN               NaN
# 1       NaN               NaN
# 2       NaN               NaN
# 3       NaN               NaN
# 4       NaN               NaN

# %%
# Count unique recipes that have a match in the Salling data
print(f"There are {merged_df['id'].nunique()} unique recipes that have a match in the Salling data")

# Group by recipe title and count the unique matched ingredients
matched_counts = merged_df.dropna(subset=['Cleaned Ingredients']).groupby('title')['Cleaned Ingredients'].nunique().reset_index()
matched_counts.columns = ['id', 'matched_ingredients_count']

# Identify ingredients from the recipes that did not have a match
unmatched_ingredients = merged_df[merged_df['Cleaned Ingredients'].isna()]

# Count the number of unmatched ingredients for each recipe
unmatched_counts = unmatched_ingredients.groupby('title')['description_en'].nunique().reset_index()
unmatched_counts.columns = ['id', 'unmatched_ingredients_count']

# Merge the matched and unmatched counts into a single DataFrame
final_counts = pd.merge(matched_counts, unmatched_counts, on='title', how='outer').fillna(0)

# Add columns for matched and unmatched ingredients
final_counts['matched_ingredients'] = final_counts['title'].map(lambda x: merged_df[(merged_df['id'] == x) & (merged_df['Cleaned Ingredients'].notna())]['Cleaned Ingredients'].unique())
final_counts['unmatched_ingredients'] = final_counts['title'].map(lambda x: merged_df[(merged_df['id'] == x) & (merged_df['Cleaned Ingredients'].isna())]['description_en'].unique())

# Display the final DataFrame
final_counts = final_counts.sort_values(by='matched_ingredients_count', ascending=False)
final_counts
# Out:
# There are 462 unique recipes that have a match in the Salling data
#                                               title  \
# 99          Gluten-free creamy chicken and mash pie
# 232                   The ultimate Christmas burger
# 234               Toffee apple self-saucing pudding
# 219                            Spiced roast chicken
# 199  Roast harissa chicken with homemade flatbreads
# ..                                              ...
# 322                     Healthy spaghetti bolognese
# 323     Healthy stir-fry with tofu and rice noodles
# 324                                Homemade granola
# 325  Honey and mustard chicken with rustic potatoes
# 461                                    Winter salad
#
#      matched_ingredients_count  unmatched_ingredients_count  \
# 99                         4.0                           11
# 232                        4.0                           28
# 234                        4.0                           11
# 219                        3.0                           23
# 199                        3.0                           15
# ..                         ...                          ...
# 322                        0.0                           12
# 323                        0.0                           14
# 324                        0.0                           12
# 325                        0.0                            9
# 461                        0.0                            8
#
#                       matched_ingredients  \
# 99   [butter, milk, cheese, cream cheese]
# 232        [butter, milk, bacon, sausage]
# 234    [butter, milk, apple juice, cream]
# 219            [chicken, butter, yoghurt]
# 199            [butter, chicken, yoghurt]
# ..                                    ...
# 322                                    []
# 323                                    []
# 324                                    []
# 325                                    []
# 461                                    []
#
#                                  unmatched_ingredients
# 99   [potatoes, wholegrain mustard, black pepper, g...
# 232  [turkey, thyme, rosemary, cinnamon, goose fat,...
# 234  [caster sugar, Bramley apples, eggs, self-rais...
# 219  [lemons, onions, orange, coconut milk, chicken...
# 199  [cumin, coriander seeds, smoked paprika, haris...
# ..                                                 ...
# 322  [olive oil, beef mince, onion, mushrooms, carr...
# 323  [garlic, soy sauce, peanut butter, ginger, chi...
# 324  [maple syrup, caster sugar, sunflower oil, van...
# 325  [chicken legs, new potatoes, olive oil, black ...
# 461  [red cabbage, green cabbage, carrots, walnuts,...
#
# [462 rows x 5 columns]

# %%
#extract final_counts to a csv file
final_counts.to_csv('data/final_counts.csv', index=False)
